# %%
import os
import pandas as pd

# %%
def extract_column_to_csv(excel_file_path, column_name, output_csv_path):
    """
    Extract a specific column from an Excel file and save it as a CSV file.
    
    Parameters:
    - excel_file_path: Path to the Excel file
    - column_name: The name of the column to extract
    - output_csv_path: Path to save the extracted column as a CSV file
    """
    try:
        # Read the Excel file
        sheet_data = pd.read_excel(excel_file_path)
        
        # Check if the column exists in the sheet
        if column_name in sheet_data.columns:
            # Extract the column and save it to CSV
            sheet_data[[column_name]].dropna().to_csv(output_csv_path, index=False)
            print(f"Column '{column_name}' has been successfully extracted to CSV.")
        else:
            print(f"Column '{column_name}' not found in the Excel file.")
    except Exception as e:
        print(f"Error: {e}")

# Example usage with absolute path
excel_file_path = r'CPCB/Producer_Registered.xlsx'  # Adjust with the correct path
column_name = 'Name'  # Replace with the column name you want to extract
output_csv_path = 'output_file.csv'  # Path to save the output CSV file

extract_column_to_csv(excel_file_path, column_name, output_csv_path)
# Out:
# Column 'Name' has been successfully extracted to CSV.

# %%
import os
import pandas as pd

def merge_csv_files(input_folder, output_file):
    """
    Merge all CSV files from a specified folder into a single CSV file.
    
    Parameters:
    - input_folder: Path to the folder containing the CSV files
    - output_file: Path to save the merged CSV file
    """
    try:
        # List to hold all the DataFrames
        all_csv_data = []

        # Loop through all files in the specified folder
        for file in os.listdir(input_folder):
            if file.endswith('.csv'):
                file_path = os.path.join(input_folder, file)
                # Read each CSV file and append its content to the list
                data = pd.read_csv(file_path)
                all_csv_data.append(data)

        # Concatenate all CSVs into a single DataFrame
        merged_data = pd.concat(all_csv_data, ignore_index=True)

        # Save the merged DataFrame to a new CSV file
        merged_data.to_csv(output_file, index=False)
        print(f"Merged CSV file saved at: {output_file}")

    except Exception as e:
        print(f"Error: {e}")

# Example usage
input_folder = r'Cpcb_csv'  # Replace with the folder containing your CSV files
output_file = r'D:\match_data\merged_output.csv'  # Path to save the merged CSV file

merge_csv_files(input_folder, output_file)
# Out:
# Merged CSV file saved at: D:\match_data\merged_output.csv

# %%
def extract_column_to_csv(excel_file_path, column_name, output_csv_path):
    """
    Extract a specific column from an Excel file and save it as a CSV file.
    
    Parameters:
    - excel_file_path: Path to the Excel file
    - column_name: The name of the column to extract
    - output_csv_path: Path to save the extracted column as a CSV file
    """
    try:
        # Read the Excel file
        sheet_data = pd.read_excel(excel_file_path)
        
        # Check if the column exists in the sheet
        if column_name in sheet_data.columns:
            # Extract the column and save it to CSV
            sheet_data[[column_name]].dropna().to_csv(output_csv_path, index=False)
            print(f"Column '{column_name}' has been successfully extracted to CSV.")
        else:
            print(f"Column '{column_name}' not found in the Excel file.")
    except Exception as e:
        print(f"Error: {e}")

# Example usage with absolute path
excel_file_path = r'MPCB/MPCB_Recycler.xlsx'  # Adjust with the correct path
column_name = 'Name'  # Replace with the column name you want to extract
output_csv_path = 'output_file.csv'  # Path to save the output CSV file

extract_column_to_csv(excel_file_path, column_name, output_csv_path)
# Out:
# Column 'Name' has been successfully extracted to CSV.

# %%
import os
import pandas as pd

def merge_csv_files(input_folder, output_file):
    """
    Merge all CSV files from a specified folder into a single CSV file.
    
    Parameters:
    - input_folder: Path to the folder containing the CSV files
    - output_file: Path to save the merged CSV file
    """
    try:
        # List to hold all the DataFrames
        all_csv_data = []

        # Loop through all files in the specified folder
        for file in os.listdir(input_folder):
            if file.endswith('.csv'):
                file_path = os.path.join(input_folder, file)
                # Read each CSV file and append its content to the list
                data = pd.read_csv(file_path)
                all_csv_data.append(data)

        # Concatenate all CSVs into a single DataFrame
        merged_data = pd.concat(all_csv_data, ignore_index=True)

        # Save the merged DataFrame to a new CSV file
        merged_data.to_csv(output_file, index=False)
        print(f"Merged CSV file saved at: {output_file}")

    except Exception as e:
        print(f"Error: {e}")

# Example usage
input_folder = r'Mpcb_csv'  # Replace with the folder containing your CSV files
output_file = r'D:\match_data\merged_output_1.csv'  # Path to save the merged CSV file

merge_csv_files(input_folder, output_file)
# Out:
# Merged CSV file saved at: D:\match_data\merged_output_1.csv

# %%
import os
import pandas as pd

def merge_csv_files(input_folder, output_file, column_name='Name'):
    """
    Merge all CSV files from a specified folder into a single CSV file with one column named 'Name'.
    
    Parameters:
    - input_folder: Path to the folder containing the CSV files
    - output_file: Path to save the merged CSV file
    - column_name: The name of the column to extract (default is 'Name')
    """
    try:
        # List to hold all the company names under 'Name' column
        all_data = []

        # Loop through all files in the specified folder
        for file in os.listdir(input_folder):
            if file.endswith('.csv'):
                file_path = os.path.join(input_folder, file)
                # Read each CSV file
                data = pd.read_csv(file_path)
                
                # Ensure the 'column_name' exists in the CSV, then extract the data
                if column_name in data.columns:
                    all_data.extend(data[column_name].dropna().tolist())  # Add the data to the list

        # Create a DataFrame from the list of all data
        merged_data = pd.DataFrame({column_name: all_data})

        # Save the merged DataFrame to a new CSV file
        merged_data.to_csv(output_file, index=False)
        print(f"Merged CSV file saved at: {output_file}")

    except Exception as e:
        print(f"Error: {e}")

# Example usage
input_folder = r'Mpcb_csv'  # Replace with the folder containing your CSV files
output_file = r'D:\match_data\merged_output_1.csv'  # Path to save the merged CSV file

merge_csv_files(input_folder, output_file)
# Out:
# Merged CSV file saved at: D:\match_data\merged_output_1.csv

# %%
import pandas as pd

def compare_csv_files(file1_path, file2_path, column_name='Name'):
    """
    Compare two CSV files and print names that are in one file but not in the other.
    
    Parameters:
    - file1_path: Path to the first CSV file
    - file2_path: Path to the second CSV file
    - column_name: The name of the column to compare (default is 'Name')
    """
    try:
        # Read the CSV files into DataFrames
        df1 = pd.read_csv(file1_path)
        df2 = pd.read_csv(file2_path)

        # Check if the column exists in both files
        if column_name not in df1.columns or column_name not in df2.columns:
            print(f"Column '{column_name}' not found in one of the files.")
            return
        
        # Extract the 'Name' column and drop any NaN values
        names_file1 = set(df1[column_name].dropna().str.strip().str.lower())  # Normalize to lower case
        names_file2 = set(df2[column_name].dropna().str.strip().str.lower())  # Normalize to lower case

        # Compare and find names that are in file1 but not in file2, and vice versa
        unique_to_file1 = names_file1 - names_file2
        unique_to_file2 = names_file2 - names_file1

        # Print the results
        if unique_to_file1:
            print(f"Names in {file1_path} but not in {file2_path}:")
            print("\n".join(unique_to_file1))
        else:
            print(f"No names found in {file1_path} but not in {file2_path}.")

        if unique_to_file2:
            print(f"\nNames in {file2_path} but not in {file1_path}:")
            print("\n".join(unique_to_file2))
        else:
            print(f"No names found in {file2_path} but not in {file1_path}.")

    except Exception as e:
        print(f"Error: {e}")

# Example usage
file1_path = r'merged_output_1.csv'  # Path to the first CSV file
file2_path = r'merged_output.csv'  # Path to the second CSV file

compare_csv_files(file1_path, file2_path)
# Out:
# Names in merged_output_1.csv but not in merged_output.csv:
# threco recycling llp
# habib enterprises
# resgen limited
# earth care solutions
# shakti corporation
# swastik plasto
# agarwal technoplast pvt. ltd.
# sky traders
# greentech recyclers
# national enterprises
# swanyog industrie pvt ltd
# pur o fuel pvt ltd
# sana traders
# deluxe recycling (india).pvt.ltd
# s h enterprises
# heramb polyflakes
# p.k.enterprises
# foram enterprises
# huhtamaki foundation
# uma plastic
# sageer ahamad shabber khan
# national plastic udyog
# k. k. nag pvt. ltd
# gayatri packaging
# nida plastics
# universal waste management
# m k plastics
# vista packaging private limited
# shree plastics industries
# shree bhavani engineering works
# rudra blue planet environmental solutions india ltd
# kalp multipack private limited
# aqsa stamping
# m k scrap traders
# gemcorp recycling & technologies pvt. ltd.
# cemech engineering industries
# polythene indusries
# m/s. mustafa traders pvt. ltd.
# suyash industries
# liberty polymers
# navbharat recycling industries
# blue star drum suppliers
# sadguru plastics
# swami samarth polyfilm industries pvt. ltd.
# mohmmad umar trader
# bright star plastic industries
# mothara industries
# soumaya sales corporation
# vasudeo polymers
# rajasthan plastic industries
# raman plastic
# malushte secuearth
# reliance industries limited, nagothane manufacturing division
# nasik plastic waste recycling private limited
# pune traders
# kesariya metal corportaion
# green oil india
# jay agro industries
# m/s.top o plast
# s r traders
# d trading company
# shree yash enterprises
# shaila plastic
# pyrotask energy
# scape e recycler private limited
# shree venkatesh enterprises
# mohan industries
# five elements environmental technologies pvt. ltd.
# patidar polymers
# om plastic
# swagatam enterprises
# meera brijmohan gupta (opc)
# viraj traders
# omega packaging
# s.s enterprises
# samarth enterprises
# shama scrap centre
# aman plastics
# m/s. ansari plastics
# clean biotech private limited
# pallavi industries
# yes industries
# technova recycling india private limited
# shakti plastic industries
# someshwar industries
# m/s. sudhiraja plastic pvt. ltd.
# ramakant sale corporation
# a h traders
# prema plastic and allied industries
# datta plastic
# smd enterprises
# international drum suppliers
# maiz trading corporation
# maa santoshi industries
# mediplast packaging nagpur pvt ltd
# gupta enterprises
# m/s. gulshan plastic industry
# indian plastic
# perfect insulation
# m/s. map trading company.
# shriram incorporated
# elegante producto pvt. ltd.
# shree ramdeo industries
# bharat industries
# advait polymers
# m/s. n. m. enterprises
# mahavir packaging
# siddhivinayaka poly products pvt ltd
# jyoti polymers
# amin plastic
# green earth polypro private limited
# a. m. industries
# modern packaging industries
# padma plast
# jai durga industries
# j choudhary and company
# diligence infraprojects private limited
# m/s neel enterprses
# albir trading co
# adarsh pet pvt. ltd.,
# sai enterprises
# supreme petrochem ltd
# sejpal plastics pvt. ltd
# santoolan enviro solutions pvt. ltd.
# m/s. champion chem industries
# ms ansh enterprises
# sunshine enterprises
# alankar polymers
# s m pawar industrial suppliers
# modi polyfab pvt ltd
# precise technologies
# royal plastic
# sara enterprises
# sneha plastic
# the hind electric and engineering corporation
# naaz petroleum
#
# Names in merged_output.csv but not in merged_output_1.csv:
# mukesh kr agarwal
# creative eyeglasses private limited
# mohan merchandise private limited
# m/s kress machinery private limited
# rajneesh kumar goel
# m/s siddhant industries
# m/s super cartons
# h s e technologies private limited
# arapl raas private limited
# shri rakesh kumar
# shri pankaj arora
# m/s noah equipment private limited
# smt dattaji kanta gadge
# maccaferri environmental solutions private limited
# biospark-healthcare private limited
# neelam
# m/s vibgyor distributors
# m/s kala associates hyd
# kleiberit adhesives india private limited
# jeipolymer
# eloquent electrotech india
# gujarat multi gas base chemicals private limited
# m/s errand enterprises private limited
# m/s 75f smart innovations india private limited
# miraclon india private limited
# isoe printpack industries private limited
# e. smile. technology private limited
# vedant traders
# m/s smile electronics limited
# shetron limited
# gagan goyal huf
# surabhi industries (india) private limited
# m/s karl mayer textile machinery india private limited
# m/s edac multitech private limited
# shri vineet bansal
# mamta arora
# m/s avishkar agro technology llp
# shri santosh khetan
# sheng long bio-tech india private limited
# lakyou beauty india
# national paper industries
# m/s colourtex industries private limited
# zanskar home solutions llp
# rachna bajaj
# mayuri arya
# m/s asian technologies
# shri parget singh paramjit singh virk
# m/s gurudatta agro agencies & services
# m/s basf catalysts india private limited
# and more stories
# ultrapack india industries private limited
# mihir vishnubhai suthar
# m/s freudenberg-nok private limited
# purushottam sharma
# prince flexipack llp
# m/s rn chidakashi technologies private limited
# shivprakash shankarlal chandak
# m/s dey's medical stores private limited
# m/s hindustan urvarak & rasayan limited
# parveen kumar
# print smart solution
# virender singh
# m/s oke electronics private limited
# tapan dutta
# regent electro-mech private limited
# m/s aerem solutions private limited
# anand aggarwal
# scientific & digital systems
# intercom skicorp manufacturing private limited
# smt sutapa banik
# m/s technova recycling india private limited
# dynamic techno medicals private limited
# karansingh rathod
# beta drugs limited
# ascensia diabetes care india private limited
# shri subroto mukherjee
# pvc colouring compounding & processing
# shri asim masood bhure
# excelsior india
# ruchi deepesh bagadiya
# m/s c tribhovandas & company
# fillchem global
# zuari industries limited
# guda sai girisha
# shri ramkaranji vishnudas dhoot
# m/s omco enterprises private limited
# m/s b t infosys pvt ltd
# m/s mkv technologies llp
# mohd taqi gulam mohd kazi
# rahul ramesh jain
# sunil suresh honrao
# enerlite solar films india private limited
# a cube tools and hardware llp
# m/s yamuna interiors private limited
# the krishna district milk producers mutually aided co op union limited
# apollo supply chain private limited
# kr lifesciences private limited
# aveo hardware (india) private limited
# m/s associated electrochemicals private limited
# anil kumar arora
# m/s jbm industries limited
# m/s dol mobility private limited
# m/s an3 techno power limited
# gtz (india) private limited
# m/s igl seeds private limited
# indo spark construction services
# shri rajan malhan
# m/s discover impex private limited
# yuvraj dugar
# shri shresth gupta
# grasim industries limited
# dlyft india llp
# honeywell international (india) private limited
# m/s osstem implant india private limited
# raj borax private limited
# m/s innovation healthcare inc.
# karamjeet singh narula
# fc tecnrgy pvt ltd
# m/s janakee industrial products private limited
# rohit madhok
# neeraj kumar malhotra
# entasis technology private limited
# s. h. engitech private limited
# m/s tritvam care services
# m/s amity leather international
# musab mohamed ibrahim shaikh
# h & m hennes & mauritz retail private limited
# stark logistics llp
# m/s go fashion (india) limited
# m/s manish c shah (huf)
# suresh kumar ruia
# voss automotive india pvt ltd
# global signs industries
# m/s a r p auto parts private limited
# ceragon networks india private limited
# garware hi-tech films limited
# westrock india pvt. ltd.
# m/s aeon international
# m/s kawasaki manufacturing (india) private limited
# manojkumar shobhnath shukla
# neelima sandeep kalke
# m/s arochem industries private limited
# m/s waco industries
# sanya jain
# shri hirabhai pareshbhai kakadiya
# m/s oriental aromatics limited
# r.g. marketing
# rajan trading co
# abdul ahad usman shethwala
# polstar
# kaynes international design & manufacturing private limited
# praveen kumar jha
# jitendra karnawat
# m/s orchid (interior decorators) private limited
# m/s edusoft healthcare private limited
# delta electronics india private limited
# yeoman marine services private limited
# m/s. poshtik food products llp
# m/s faster hydraulics private limited
# alwar zila dugdh utpadak sahkari sangh ltd
# m/s accent industries limited
# shri salikram radheshyam pal
# shri govind sri singh
# igk technical textiles llp
# neha ghisulal jain
# m/s techfab (india) industries limited
# ashok bansal
# m/s endura superabs pvt ltd
# m/s shanti overseas (india) limited
# m/s genuine seeds private limited
# rinkesh traders
# sunil mehta
# m/s rak vertical solutions private limited
# mepro pharmaceuticals private limited
# mvm industries
# m/s eclipse global private limited
# bharat sirohia
# m/s varmora ceramics private limited
# schlumberger asia service ltd
# nikesh madanlal agarwal (huf)
# m/s atlas ro systems
# m/s vee rubber india private limited
# mustan saiffudin lakadawala
# devang p mehta (huf)
# mohammad mohsin azhar
# shri deoram vivek bhangre
# m/s halol leather cloth private limited
# interioworlds
# meghalaya cements limited
# m/s kay consumer products private limited
# jcb india limited
# m/s united medi-equip private limited
# ninesky technology and industrial private limited
# m/s bhimrajka mader coatings private limited
# bharat products limited
# payal goel
# shri bhaskarrao kishor bhalerao
# sayar tokrshi mehta
# tarun gupta huf
# arcum impex llp
# m/s chappaly industries (opc) private limited
# jcs impex pvt ltd
# m/s suresh indu lasers private limited
# microsoft corporation india pvt. ltd.
# vijaybhai dhanjibhai dhorajiya
# radiant polychem private limited
# m/s african caribbean aloe sales (india) private limited
# mediser scan technology private limited
# ojas footwear india private limited
# garg seasonwears
# diplast plastics limited
# m/s jumbo dates
# m/s r s graphics
# unique india engineers
# ahad trade private limited
# time technoplast limited
# paramvir power solutions llp
# trent limited
# m/s novartis india limited
# kirti velji thakkar
# rachana amit alimchandani
# goldstab organics private limited
# loghorn industries pvt ltd
# shri chunilal haresh rajani
# balajee techno polyfabs private limited
# checkpoint apparel labeling solutions india private limited
# shree harikrushna food
# m/s jainson sales
# mustafa ahmed ali master
# m/s jyoti resins and adhesives limited
# unicorn international
# m/s scs industrial product manufacturing company private limited
# m/s gedia india automotive components private limited
# farzeen salman chhapra
# narsi ranchhod ravaria
# satyendra food products private limited
# shri seetharama rao venkata vemula
# penna cement industries limited
# colourtex industries private limited
# blumenotics pvt limited
# m/s dhanaprakash industrial corporation
# smt bharat santoshi pitani
# param pharma
# ace polymers
# suresh kalra
# m/s micro village communications private limited
# prathamesh industries
# kunal mittal
# nidhi govindsingh kharayat
# shri osman tofik gigani
# indian polymers
# sunlit power private limited
# paviour pharmaceuticals private limited
# m/s sujan industries
# m/s aquaprufe industries (india) private limited
# m/s austin palms llp
# g m tea packers private limited
# m/s v k engineering
# sudha dhir
# raj kumar khemka
# m/s saga pesticide private limited
# m/s gurudev dye-chem private limited
# advy chemical private limited
# advantage automation
# m/s tnt infratech india private limited
# m/s genpure technologies pvt ltd
# m s textiles
# supreme tech
# venki chem
# thakur enterprises
# m/s arun garg (huf)
# newtech synergy systems private limited
# west bengal chemical industries limited
# m/s sudha ventilating systems private limited
# m/s schneider electric it business india private limited
# m/s derewala industries limited
# moha packaging india private limited
# m/s myk arment private limited
# igw india technologies private limited
# shri tarun khanna
# darshan foods pvt ltd
# vijay impex
# gracetech marketing
# m/s kantil pharmaceuticals private limited
# m/s kyowa electronic instruments co.ltd
# fablino textile private limited
# dynamic it solution private limited
# nyutan dattaram shirke
# shri ashwin sumay gokani
# horology impex co
# anil kumar taneja
# pradeepkumar gopinathan
# kiddel technologies india private limited
# william automotive electrical supplies private limited
# archna agrawal
# ssf technoplast ( a unit of ssf plastics pvt ltd)
# m/s products & ideas (india) pvt ltd
# vikram nemichandji chandan
# ralli agrotech limited
# sara exports ltd
# tcpl halma private limited
# tuisha impex private limited
# kf bioplants private limited
# siddik yusuf metar
# shri manoj gupta
# rosewood laminates pvt ltd
# m/s krisid trading private limited
# bidar chemo trades
# glitz finishing products llp
# mukesh mohanlal jain
# dhaval gautamkumar patel
# prime solwood india private limited
# hari shankar prasad santosh kumar
# pentagon plastic industries private limited
# m/s eurobelt belting solutions private limited
# bharat mandan choudhary
# m/s eveline international
# shri ukabhai pravinkumar patel
# m/s boxseat ventures private limited
# m/s advanta enterprises limited
# itl industries limited
# m/s bihani chemical industries private limited
# m/s sciex india private limited
# manmachine car care private limited
# shri kekin gandhi
# r s preethi jyothsana
# m/s prantae solutions private limited
# smt uzma ambia
# innovative solutions
# shri chandan singh
# m/s beejapuri fresh products private limited
# endico power tools (india)
# plata industries private limited
# bajaj chemicals
# sachin bhupendra desai
# shri amit puri
# shri arpan uppal
# rajalakshmi chemicals
# perennials india private limited
# industrial metal powders (india) private limited
# m/s trisha renewable energy private limited
# indiana ophthalmics llp
# excel plant link private limited
# m/s oneplus technology india private limited
# m/s aayirp (opc) private limited
# shri manekshaw jahangir contractor
# shri sourabh maheshwari
# m/s infinito international
# m/s vivek agarwala huf
# smt alka jain
# shri thangavel latchumanan
# master alloys limited
# ramgopal premsukh malani
# universal trade links
# kanda jagdeep singh
# overseas polymers private limited
# wuerth industrial services india private limited
# labdhi polychem llp
# shri dova ram
# m/s shikhar impex
# supreme marketing
# bankim plast private limited
# prem chand
# shri kumar swapan howladar
# bhagul industries
# khusbu gupta
# shri juber mohammed irfan motiwala
# trrado india corporation
# pee cee cosma sope limited
# sumr plast tech india llp
# transchem corporation pharma private limited
# m/s biospan contamination control solutions private limited
# babulal himmatmal jain
# m/s skydrift innovations private limited
# rajnikant popatbhai vaghani
# puniska injectables private limited
# blaze analytical instruments llp
# m/s workplace synergies private limited
# m/s reliable marine and logistic services private limited
# thermax babcock & wilcox energy solutions limited
# m/s shri daulat exim private limited
# m/s k3m industries llp
# m/s shri vinayaka creations
# satol chemicals private limited
# aero walk international (india) private limited
# shri anjani garg
# aadhya shree creation
# rajender kumar aggarwal
# m/s murata machinery india private limited
# m/s wood craft clocks private limited
# green particle biotech private limited
# mehul anupchand mehta
# laxmi dental export pvt ltd
# rajesh hastimal jain
# gautam dwarkadas asudani
# m/s sujan contitech avs private limited
# jk associates private limited
# joglekar refractories private limited
# smt devi suman baid
# shakambhari ispat & power limited
# acker scientific
# hutatma sehkari dudh utpadak sangh
# neovenlab instruments and services llp
# sushil kumar
# m/s kalpvraksh impex pvt ltd
# flair writing equipments private limited
# raj narain pratap narain rolling enterprises private limited
# m/s aura print solutions private limited
# jamsheer k p
# m/s jay balaji polypack
# krishi geopack private limited
# everest tent technologies
# shri kumar prasan banthia
# alto medical systems private limited
# shri narinder jindal
# shri manoj baid
# ravikumar r patel
# anil kumar rathi
# shri bhikhubhai jatin gajera
# lotus herbals private limited
# mehta and sons
# hope ceramics machinery (i) private limited
# shri adish jain
# pushpanjali medi india private limited
# mark tech polymers private limited
# shri harshit khandelwal
# m/s jain plastic bhandar
# shakir gulamrasool ghojaria
# m/s lambert lighting product private limited
# mohit ashokbhai patel
# m/s stylcove modulars private limited
# orianaa decorpack pvt ltd
# unistar technoplast private limited
# nayan bohara
# gm machine tools private limited
# sspr valve manufacturing private limited
# shri sumit malik
# h k international
# lml emotion private limited
# genting crop sciences private limited
# glaxosmithkline pharmaceuticals limited
# r m co
# shyam international
# m/s q-line biotech private limited
# novozymes south asia pvt. ltd
# dipti rajesh totla
# c.g enterprises
# universal trading company
# m/s shreeji international
# m/s hyper pack private limited
# sabyasachi calcutta llp
# universal sportsbiz private limited
# m/s avyye yarns private limited
# chetan das om prakash impex private limited
# sunny synthetic
# zuventus healthcare limited
# g m polyplast limited
# m/s kesari polymers
# jsk international
# m/s vipul chemicals india pvt ltd
# m/s palvi industries limited
# m/s gfcl ev products limited
# m/s okinawa autotech internationall private limited
# karan vohra
# cascade india material handling private limited
# m/s cytiva india private limited
# smt mala pethaperumal
# arktron electronics
# shri remtluanga matthew sailo
# pollo luggage
# ravi agarwal
# bhaskari aqua products private limited
# m/s indtex engineers limited
# swarnjit singh panesar
# smt shanisha kent
# m/s libral traders private limited
# shri shiju
# bagaria trading private ltd
# m/s gulmohar health care private limited
# tara vijaykumar mundada
# shri himatlal bhupesh shah
# mankind consumer healthcare private limited
# m/s bst eltromat india private limited
# chariot properties llp
# deepak shantaram joshi
# fahad hanif parmar
# goma cleantech private limited
# luna impex
# shri jitendra sanghavi
# m/s labquartz silica private limited
# bharath veer katakam
# m/s haygrove india private limited
# m/s namdeo umaji agritech (india) private limited
# cosmos twisters private limited
# adn services
# vinchem industries private limited
# m/s lawson lucy india private limited
# techmax lighting co llp
# choudhary products india
# rustoppers packtech private limited
# orbikem llp
# win pens private limited
# phagwara auto parts
# mlj industries limited
# satidadi agro manufacturers private limited
# musashi auto parts india private limited
# vijaya shankar iyer
# lupin manufacturing solutions limited
# m/s smj venture private limited
# m/s hks international
# dilipkumar & co.
# walter pack automotive products india
# deepak sethi
# calcutta colour company
# tata communications collaboration services private limited
# monica gupta
# m/s jjg aero private limited
# m/s hotel kannappa grand gardenia
# geistlich pharma india private limited
# trinity filtration technologies private limited
# smt girish neelam gupta
# m/s avik pharmaceutical limited
# smt mandakini samal
# m/s laxmi narayan corrugated boards llp
# rajni rustagi
# labtech medico private limited
# m/s sanj exports
# meghasgs international private limited
# gagandeep singh
# the master packaging
# mohammed kazim ahmed taher shaikh
# m/s raj chaton industries private limited
# m/s wiska india private limited
# m/s the printers house private limited
# nileshkumar pramodbhai bhatt
# plast technology india private limited
# purpleark life private limited
# m/s 3d technopack private limited
# anthem biosciences private limited
# smt rachi mehrotra
# m/s elconconnectors cables private limited
# pravin kumar sinha
# nirmal poly plast pvt ltd
# enayat agro foods private limited
# yutika natural private limited
# mohd ashraf mohd amin rangunwala
# salasar technotex private limited
# m/s jainson woolcombers private limited
# m/s waves aircon private limited
# metlok precoat services private limited
# jaiminee tak
# m/s aaurum enterprise
# shri anil abhijit shah
# shri ahmed faiz patel
# m/s enren energy private limited
# beejapuri dairy private limited
# ami organics electrolytes private limited
# plasma spray processors private limited
# cwg water treatment private limited
# waaree technologies limited
# raut chandrashekhar b
# shri satish manickarajan
# m/s dynamic techno medicals private limited
# m/s datasensor india private limited
# elgi sauer compressors limited
# orissa metallurgical industry private limited
# m/s sulochna retail mart private limited
# m/s berth audio private limited
# patel piyushkumar
# upg technologies (india) private limited
# faqir chand vinod kumar and company
# apcotex industries ltd
# alectrak corp
# shri abbas hussain pardiwala
# startsense entertainment india private limited
# homebrew automation solution
# shri rustam mohammad ali
# m/s anron metalisers private limited
# medtech life private limited
# avishkaran industries private limited
# m/s the refrigeration house
# m/s yashash commodities private limited
# lata jain
# m/s raymond limited
# vikas kumar
# mack sewing machine systems
# globus agrofoods private limited
# sidh masterbatches private limited
# m/s evonith metallics limited
# aniruddha vivekanand doke
# michelman private limited
# greenlam industries limited
# m/s abros sports international private limited
# bharat bhushan
# m/s shital chemical industries
# m/s cases villa private limited
# cotex chem private limited
# shri bikram bakshi
# suresh chandra upadhyay
# m/s dayton tools
# plutusone hospitality private limited
# m/s jaka overseas
# thriveni earthmovers private limited
# shri gurvinder singh malhotra
# godrej industries limited
# m/s star imports
# m/s avtrans technologies private limited
# franklin anthony david
# icpa health products limited
# gudhka brothers
# prakashbhai narayanbhai sonar
# m/s naari pharma private limited
# m/s shakti polyfab
# m/s jamna auto industries ltd
# vibha ecopac pvt ltd
# bisotech india private limited
# m/s autoneum india private limited
# jace impex
# azhar traders
# schurter electronics (india) private limited
# shri rajendra abhishek raniwala
# vijaykumar hemraj nisar
# tangerine skies private limited
# pratik satyajit majumdar
# bisou cosmetics private limited
# hind high vacuum company private limited
# shrirang automation & controls
# m/s helios offshore private limited
# shri giriraj soni
# danisco (india) private limited
# sachin satish desa
# ample graphics private limited
# mahmood alam
# fragrance & aroma eastland private limited
# m/s ethics traders
# kumar snacks products private limited
# m/s blooms india incorporation
# india pesticides limited
# m/s maximus modular systems
# m/s sagar grandhi exports private limited
# jugmander dass jai bhagwan and company
# smt pistadevi
# shri singh harmeet bedi
# patel mohammad hasan shoaib
# shri ashish bansal
# anmol industries limited
# m/s banaras beads limited
# m/s oneweb india communications private limited
# h k tannery
# m/s makson healthcare private limited
# jell pharmaceuticals private limited
# m/s c k fabrics private limited
# m/s finolex cables ltd
# jay krishnakant bhuta
# m/s komax automation india private limited
# shri pal mahender singh
# m/s ralson tyres limited
# ratan projects & engineering co. private limited
# m/s bhagwati impex
# m/s sap industries
# hi tech international
# vivre panels private limited
# m/s aldeko panels private limited
# muffaddal taher lokhandwala
# shri vishwanath vinay shelar
# agromech industries
# yogikuti private limited
# essix biosciences limited
# m/s zoller india private limited
# m/s uttara foods and feeds private limited
# mupro india private limited
# praveen jayantilal bagrecha
# ankush enterprises
# pds trading & warehousing company private
# shri chand gopal taparia
# papami toytronix private limited
# dixon technologies (india) limited
# m/s cruise electric private limited
# satish kumar gupta
# m/s lamberti india private limited
# khunt bhaveshbhai bharatbhai
# rishi fibc solutions private limited
# aashmi traders
# o k glass fibre private limited
# siselectron (india) private limited
# sanjoy barua
# pes engineers pvt ltd
# grk advanced metallurgy corporation
# m/s kuloday technopack pvt ltd
# m/s blv healthcare private limited
# m/s all india tools centre
# hiteshbhai ratilal hasalia
# invisalign india llp
# sri shwasthik vardhanahh company
# s.s. food industries
# m/s stewols india private limited
# nitu hora
# kirloskar ebara pumps limited
# k n c agro limited
# neo sun industries limited
# manoj kumar bhatt
# divekar wallstabe & schneider precision seals private limited
# karan polymers private limited
# dwij polymers
# m/s daksh sales corporation
# dazzling pvc industry
# m/s haldia energy limited
# shri thiyagarajan chidambaram
# prateek gangwani
# m/s unitech glass tech private limited
# jay bharat shah
# ishvarbhai valjibhai koshia
# m/s alaina healthcare private limited
# bhadani trading company
# m/s bafna devices private limited
# paras spices private limited
# indorama india private limited
# m/s allied instruments and thermocouples
# tanya mahajan
# rex sealing and packing industries limited
# chetan vasantlal parekh
# windlas biotech limited plant2
# ctm geosynthetics india llp
# gromor agro india
# m/s willstrong solutions private limited
# m/s mahindra defence systems limited
# m/s grauer & weil (india) limited
# m/s vignesh polymers india private limited
# raman leathers
# madhepura electric locomotive private limited
# m/s zf commercial vehicle control systems india limited
# nanoskool education private limited
# franklin fueling systems india private limited
# m/s hyperbudget super market
# smt varsha agrawal
# smt bhargavi
# vidhyadhar suresh parmekar
# vectradigi technologies llp
# vizin india private limited
# garg duplex & paper mills private limited
# abdullah mohammed yunus dokadia
# vilok chitramal maloo
# uni medico labs
# anilkumar roshanlal dhakad
# precihole machine tools pvt ltd
# mehta cosmetics private limited
# shreya containers
# archimedis healthcare private limited
# shikhar agro
# aslam usman gaziyani
# accretion industries
# m/s advance agrisearch limited
# j m t plasp private limited
# dharmendrakumar sevantilal shah
# global industrial spares
# srs innovative solutions
# techvon infotech india private limited
# parmeshwar impex private limited
# canafa solutions private limited
# shobha muralidharan panicker
# m/s otc daihen india private limited
# madhav world
# m/s anand tradelink private limited
# m/s aegis lifesciences private limited
# shri kumar kishan suthar
# park pharmaceuticals
# m/s amrut energy private limited
# shri vasant milan shah
# wizbro ventures private limited
# kpl international limited
# roongta garments private limited
# m/s koncept polypro private limited
# mahadev techno private limited
# shah plywood
# j t c metallon private limited
# m/s kutwal foods private limi ted
# phoenix overseas
# m/s devi fisheries limited
# shri ashish khanduja
# shangi food products
# the greenovators
# petrochem asia private limited
# m/s impressive intex private limited
# hunny bajaj
# mohit gupta
# p&amj private limited
# nexus crop science private limited
# uttam chand rakesh kumar
# opal enterprises
# radheraman rice processing private limited
# m/s hill take international
# manchanda sales
# m/s innova rubbers private limited
# tyco safety products (india) private limited
# tej shoe tech
# axia plastics private limited
# shri dana rajesh majeri
# motilal agrawal (huf)
# scrubex corporation
# farmland premium foods llp
# m/s roton consultancies private limited
# v.k. agriculture equipments private limited
# m/s petrorub polymers private limited
# t. m. printers private limited
# oyster medisafe private limited
# ramavtar sodhani
# m/s tuf metallurgical private limited
# s r v international private limited
# raychem rpg private limited
# united brands of shisha india private limited
# aashna handicrafts private limited
# orion overseas
# oran international ventures private limited
# shri prashant kumar
# m/s mukesh s kothari huf
# shri preekshat bhasin
# m/s reparar works private limited
# bipin vasant patel
# hari mangharam advani
# s k singal and sons huf
# m/s licorne commodities private limited
# m/s somemiya corporation private limited
# m/s dozer world private limited
# shri anwarhussain mulla
# pramod kumar mittal
# shri narayan raju jituri
# shri bharat mandal
# palak agarwal
# m/s vardan metal industries
# city elevators private limited
# vikash kumar verma
# m/s zorba international
# c. and c. laser engineering private limited
# shri charat khetan
# tpi india limited
# sunrise international
# yushka cosmetics llp
# m/s msl driveline systems limited
# arcedior international private limited
# marposs india private limited
# jainii trexim private limited
# esstex engineering and trading company private limited
# toshvin analytical private limited
# shri kasi senthil kumar nadar
# m/s seth fastener tools
# s b impex
# mico plast industries private limited
# jayant bhansali
# m/s yash rasayan & chemicals
# m/s ritspin synthetics ltd
# innova holdings pvt ltd
# ajanta pharma ltd
# compak
# shri jatin arora
# m/s bengal wire machinery
# m/s metalman auto private limited
# ivl dhunseri petrochem industries private limited
# m/s masterhill (india) private limited
# ideal chemi plast pvt ltd
# rgp impex private limited
# m/s madanlal m sharma
# m/s eastern poly craft industries ltd
# sidmark sales synergy llp
# dharam pal rawat
# m/s mars toolings
# m/s busch vacuum india private limited
# lotus beauty care products private limited
# m/s yuvraaj hygiene products limited
# shailesh jaywantlal gandhi
# shah products
# mohammed mudasir hussain
# shrinath rotopack (mp) private limited
# saroj impex llp
# m/s k l engineering works private limited
# m/s ace engineers
# cygnett corporation
# m/s supersonic distribution and services private limited
# manjula dhirajlal jikadra
# g m polymers private limited
# m/s gce india private limited
# m/s shakambhari overseas trades private limited
# m/s apcotex industries limited
# alfa precision technologies private limited
# inexus biotech private limited
# akbar ali gafoor ali sayed
# raghuvir kumar gupta
# vibrant specialities
# shri vipul gupta
# m/s deepak industries limited
# howework spaces private limited
# shailendra rambilas bhandari
# shri ripen agrawal
# progressive packaging solutions
# mobase electronics india private limited
# evonik india private limited
# m/s gps renewables private limited
# smt archana kiran khilari
# bmr hvac limited
# m/s arien impex private limited
# dlecta foods private limited
# wockhardt limited
# m/s aira euro automation private limited
# mbc import elite
# julekha ahmad chaudhari
# m/s ncgb marine pvt ltd
# m/s dicuria private limited
# arvind lifestyle brands limited
# jaka associates
# shri vikas kumar
# vikas dinesh kothari
# shri priti kothari
# raj kumar malhotra
# m/s lalit roop madhrani (huf)
# tanjoure sankaran ganesan
# m/s curtex furnishing private limited
# superslides and ballscrews company india private limited
# naulakha industrial corporation
# m/s mn crop & fertico private limited
# m/s healy world trading india private limited
# shri singh gagandeep kindra
# k anandan
# m/s ego wall decor private limited
# tectronics engineers
# aarumugam sakthimanoj
# aurica
# supratimm impex private limited
# tte technology india pvt ltd
# m/s aslomal vijay kumar
# opac polymers
# avarom overseas private limited
# amit chopra
# systronics india limited
# sheetal jain kishan
# manoj kumar baid
# la opala rg ltd
# m/s nihon denkei india private limited
# brightup technology private limited
# path engineering india private limited
# shri jaylesh nirav kakkad
# dairy classic ice creams pvt ltd
# m/s star's cosmetics india private limited
# m/s enkei wheels (india) limited
# m/s bengal power corporation
# m/s patran spintex llp
# acciona energy india private limited
# garuda international
# lucky star trading
# pramod kumar jaiswal
# hansraj khatri
# anil gupta
# m/s avant dekor impex llp
# chaizup beverages llp
# m/s blue dot brdg india private limited
# m/s b l polymers private limited
# indus petrochem limited
# krishna enterprises
# m/s axardeep industries private limited
# plastify private limited
# m/s bharat balloon house
# shri ali mohamed mohamed irfan bhagwani
# shabir ahmad rather
# shri kumar basant aggarwal
# m/s la loca maria llp
# m/s caplin point laboratories limited
# agastya invention private limited
# shri danish ahmed
# morcom induction private limited
# paghdal sonalben milankumar
# m/s grandway testing instruments india private limited
# smt dahyabhai bhumika mangroliya
# m/s sagar nutriments private limited
# m/s roger motors private limited
# kanchan chopra
# rg global trading company
# parveen singal
# himaliyaa traders
# m/s kangaroo impex
# m/s excel associates private limited
# m/s vermont technologies private limited
# vsk polyfins pvt. ltd.
# altitude chemcare private limited
# m/s unisafe enterprises
# shri jitendra piplani
# rama vision limited
# shri balaji traders
# sheetal
# shri rangrao kashiling hajare
# m/s cedrus silicone private limited
# hydrobaths ramco marketing private limited
# western steel traders
# shri vasant rupesh more
# midas import corporation
# shri madanlal rinkesh jariwala
# ayush pharma and chem llp
# sony india private limited
# m/s parasmal fozhraj sanghvi huf
# m/s damro furniture private limited
# tasneem kaizer pardawala
# gururaj steel
# mahavir plastic works
# jns instruments ltd.
# shri dimple sharma
# neerad keshri
# imtiyaz husain anwar husain sayed
# ravindra natthuji tikkas
# triveni engineering and industries ltd
# m/s siam cement big bloc construction technologies private limited
# m/s orange city furnitures
# popular agencies
# kathiriya vijaykumar h
# aspire solar llp
# koppern maco services private limited
# bio med private limited
# m/s bp-exim
# metro floors inc
# rama kant gilada
# m/s zentiva private limited
# brandworks technologies private limited
# eb products private limited
# shri vivek saraogi
# marksun dyestuff industries
# m/s arco life science (india) private limited
# suraj chandraprakash shah
# m/s hfn it services private limited
# gagan aneja
# m/s aranax medical private limited
# shri ankush jain
# sant all sports private limited
# heetesh shantilal gala
# m/s monte carlo fashions limited
# anuj gupta
# shri nikhil handa
# sanjay juneja
# wep solutions limited
# g b r hatcheries private limited
# harvest prime nutrimax private limited
# sew-eurodrive india private limited
# m/s raj cycle company
# m/s c mulji traders
# pragati raw pharma pvt ltd
# srinivas rao vinnakota
# imerys vizag private limited
# m/s kitex apparel parks limited
# smt tanima mallick
# aditya kumar halwasiya
# m/s gag informatics systems private limited
# sigma carbon technologies
# kurseong computer sales private limited
# lapl automotive private limited
# sejal anup shah
# salora international ltd
# m/s euro medi tools private limited
# shri archit sharma
# ravi kant jajodia
# shri kumar pawan garg
# kailpar engineering company private limited
# m/s hansa-flex (ifp) india private limited
# m/s purbanchal krishi vikas private limited
# jamunesh imex
# m/s hans metalloys
# madan gopal jhunjhunwala
# harsh rasiklal chhadva
# shri pulkit madaan
# shri saugata banerjee
# smt sheela khandelwal
# habiba iqbal saeed
# allmarc industries private limited
# hindustan global
# vkscc info solutions private limited
# m/s h s & sons
# pom systems and services private limited
# devendra rameshchandra shah
# duplets electronics private limited
# shri amit mittal
# shri saurabh aggarwal
# lloyds engineering works limited
# m/s fibre abrasive machineries private limited
# ample technologies private limited
# khetan extrusions private limited
# federal-mogul ignition products india limited
# trans trade exports
# btl india private limited
# mohan lal aggarwal
# m/s kendrix global ventures llp
# symmetry interiors & building solutions private limited
# care fresh international
# cameron (singapore) pte. ltd
# faurecia india private limited
# m/s reliance jio infocomm limited
# m/s premier energies international private limited
# trishul enterprises
# a r marketing
# shri govind mittal
# smt mamta goyal
# m/s innovative solar solutions
# merino international
# shri kumar vijay chaudhary
# m/s pristine associates
# vardhaman 925silver jewellery llp
# u liva nutrition llp
# jay kumar yadav
# nandini ajay mehta
# source one industrial supply
# brio interactive technologies private limited
# thomson impex
# tribeni worldwide pvt. ltd.
# m/s numerical analytics instruments private limited
# s m g trading co
# prateek sonthalia
# m/s gls enterprises
# indyblu
# epp composites private limited
# vonee panells industries
# palmflex packaging private limited
# dynamic eyewear llp
# lumens aircon private limited
# s v enterprises
# synflex elektro private limited
# parekh integrated services private limited
# srinath ji exports
# nitin mahendra shah
# mosca india packaging pvt ltd
# bhalani yagnik kamleshbhai
# adishwar auto ride india private limited
# bala parbat chamriya
# skc trading co
# m/s kirloskar ebara pumps limited
# smt inderjit kaur
# shri subhash chandra agarwal
# golden tools
# padia enterprise
# rayhan siraj ali achwa
# rod wheel technologies private limited
# pushpendra kumar jain
# voltson india
# devi karam associates
# sayga corporation
# smv beverages private limited
# azakta trading private limited
# decathlon sports india pvt. ltd
# aum adhesives private limited
# shri sushil kumar taparia
# m/s aureole rubbers private limited
# nasir sardar hussain hussain
# m/s mg materials
# mohamad shafiqe
# terrapreta international private limited
# raylense opto electronics industries private limited
# felder woodworking machines private limited
# kriya medical technologies private limited
# gangotri flexitubes private limited
# chandan paper corporation
# dolphy india private limited
# m/s saitech it private limited
# shri jamnadas pareshkumar sinojiya
# packem umasree private limited
# sai international
# conpol industries private limited
# jasch industrises limited
# shri anant goel
# m/s sasvat omnicare private limited
# modern masti private limited
# shri manish saboo
# m/s dalmia cement (bharat) limited
# jaishil sulphur & chemical industries
# kridwinn innovations private limited
# shri sujeet kumar
# jindal steel & power ltd.
# m/s euro labs
# shirdi sai electricals limited
# sea bird refrigeration pvt ltd
# kankriya enterprises private limited
# jajodia jyoti
# m/s richfield fertilisers private limited
# aardem polymer
# arav exports private limited
# yasho industries limited
# m/s virgo aluminum limited
# m/s pratibha syntex limited
# mann nutritional products private limited
# shree jayalakshmi enterprises
# kaumudi titus passanha
# m/s windor india private limited
# durga mechatronics private limited
# pankaj bhatia
# m/s cibes lift india private limited
# inteltek automation jv
# m/s ktwo healthcare private limited
# forace polymers private limited
# lucy electric india pvt ltd.
# rahul shokeen
# vimal dairy limited
# m/s national pipe products
# m/s globex enterprises llp
# trom industries limited
# shri ishwarlal mayur mahuvakar
# hi-tech blow moulders pvt ltd
# johnson controls india private limited
# intercos india private limited
# orissa metaliks private limited
# r h industries
# hanu polymers private limited
# polyplex corporation limited
# m/s ahuja framers private limited
# m/s thor chemicals india private limited
# schmersal india pvt ltd
# m/s unboxrobotics labs private limited
# m/s mahyco private limited
# multilink
# shri parshottam ajaykumar ginoya
# mc-bauchemie india private limited
# tarsons products limited
# vishnu mineral industries
# j.k.overseas
# rk agri biz llp
# m/s supreme nonwoven industries private limited
# lucent aquatech private limited
# becker robotic equipment india private limited
# m/s weldman synergic private limited
# vipul vijay chopda
# m/s eroyce motors india private limited
# shri jayantilal bankimchandra mandviwala
# j.b international
# shri jayantilal piyush shah
# m/s toray international india private limited
# m/s greenply speciality panels private limited
# jsm international
# m/s bay living private limited
# skydecor laminates private limited
# m/s nissei electric india private limited
# atul paper pvt. ltd.
# shri nitesh shaw
# xceed toolings private limited
# m/s caplin steriles limited
# kartavya ahuja
# conic systems private limited
# m/s khimji ramdas india private limited
# m/s p m c rubber chemicals india private limited
# sakirhussain iqbalhussain
# m/s unison batteries (india) private limited
# m/s bloomart stationery private limited
# shri anurag ruhela
# hil india limited
# m/s akarui networks private limited
# xdx fasteners india private limited
# nirakar kalucharan malla
# rajpal sachdeva
# anvayaa kin care private limited
# m/s motherson bergstrom hvac soloutions private limited
# shri govind kedia
# m/s qubeplast packaging solutions llp
# tata autocomp gy batteries private limited
# ellvees infinite llp
# reach global india private limited
# wiegand india private limited
# reliance retail limited
# beston sky vision private limited
# m/s zavenir daubert india private limited
# shri kuldeep choudhary
# balaji enzyme & chemical private limited
# heni drugs pvt ltd
# aurolab trust
# pravin shankarlal jain
# enmarol petroleum india private limited
# smt anil param dubey
# innovative speciality ingredients private limited
# soumya saha
# merchem limited
# m/s priya encase private limited
# two-sheaf computers private limited
# m/s kabir leathers
# jaypee engineering and hydraulic equipment company limited
# shri dineshbhai meet vekariya
# m/s fabro leather industries llp
# m/s amateurs trading private limited
# sonalac paints and coatings llp
# sudhir kumar agarwal
# vinit gloves manufacturing private limited
# voltkon switchgear private limited
# shri singh gurminder sawhney
# bacca bucci fashions private limited
# detailing devils india private limited
# shri deepak jain
# shri kumar surendra verma
# shabbir samad hafizi
# shri raghav goel
# shri ankit soin
# gholam shabbir
# raman traders
# mohinder agencies
# m/s regent trading company
# shri gaurav kushwaha
# m/s larkai healthcare private limited
# ulai enterprises private limited
# m/s wartsila voyage limited
# m/s starlac glass private limited
# m/s shree krishna controls private limited
# m/s singhania alu foil containers manufacturing company
# evident scientific private limited
# smt sushma rai
# sarbhara food and beverages llp
# yash pandurang sawant
# shri kapil nagpal
# maruti poly trade
# johnson india
# shri shankarbhai rajnikant patel
# mitu anil duhlani
# shri yashwant ankush warulkar
# m/s richaco exports private limited
# mumuso retail private limited
# m/s sanmar matrix metals limited
# kevinkumar sanjay desai
# m/s tata power solar systems limited
# m/s sk enmove india private limited
# bhavik enterprise
# ravi prakash dwivedi
# m/s elvy lifestyle private limited
# shivank udyog limited
# m/s esjaypee mercantile global private limited
# m/s robus india industries private limited
# viechemie skicorp technology solutions private limited
# m/s aristo laboratories private limited
# shri bhanwarlal kiran jogani
# shri niranjan kunal choksi
# m/s hover barrel limited liability partnership
# m/s electroquip
# m/s lifestyle foods private limited
# shri jayantibhai rushil patel
# umesh ghanshamdas ramchandani
# smt deepa malhotra
# shri nikhil agarawal
# m/s califonix tech and manufacturing private limited
# winomechanic private limited
# m/s total tools and equipments private limited
# smt sabeeta ratra
# modi mattresses private limited
# privi fine sciences private limited
# m/s guma tech marine services
# m/s asti electronics india private limited
# comodo living (opc) private limited
# shri ganga kanji bhandva
# m/s yamuna lubricants pvt ltd
# shri arokia raj
# m/s jai auto private ltd
# ecox inc
# m/s dhanavantari technology private limited
# m/s titan aeration company private limited
# jay ashwin karania
# kaomni trading private limited
# laxmikant co, industrial
# bhaveshbhai rameshbhai jain
# laxmi organic industries limited
# the mineral & chemical corporation
# hafsha trading pvt ltd
# gir enterprise
# m/s hamburg sud india private limited
# iftekhar alam mohammed shafi chaudhary
# m/s bajajsons limited
# shri taranpreet singh
# m/s s. s. tins private limited
# suresh khatanmal rahindani
# global colours and chemicals limited
# m/s irm energy limited
# m/s sreejan infrastructures
# sagar trading co
# cryonet
# mohd arif abdul razzak moosani
# stec hotel wares llp
# seven seas distillery private limited
# sbl specialty coatings pvt ltd
# megmeet electrical india private limited
# shri manan sukhpal
# rajesh ram gangwani
# middleby celfrost innovations private limited
# sri manjunath foods and packagings pvt ltd
# vinod b khatri
# ganpatsingh nensingh bhayal
# nayasa multiplast
# m/s sporting syndicate international private limited
# m/s samvri trading company private limited
# timir rasik doshi
# m/s davison instruments private limited
# saugaat inc
# smt monika sharma
# kgpco india private limited
# shankerdas santdas moriani
# m/s helius impex (opc) private limited
# m/s raf imports llp
# hrg trading private limited
# m/s electronic enterprises (india) private limited
# zebronics india private limited
# phoenix medical technologies and imports
# harish agrawal
# hussain saifuddin tambawala
# bhagwati cotton and spinning mills private limited
# kamaths ourtimes icecreams pvt ltd
# m/s vinayak international
# talha abdul hamid merchant
# crystal india services
# m/s waimea denim fashion private limited
# shehzan ahmed saifi
# m/s bridgestone india private limited
# enders industries limited
# s j s enterprises limited
# timken india limited
# sagar international
# sankhla vinyl private limited
# m/s maheshwari wires private limited
# m/s bharaj machineries private limited
# ball beverage packaging (india) private limited
# oswal woollen mills limited
# flash electronics india pvt ltd
# m/s vasudha recycling company private limited
# m/s premier (india) bearings limited
# m/s gurudev exports
# m/s parson adhesives india private limited
# rajinder singh
# kakkad khushiben vijaykumar
# m/s cam tools industries private limited
# kas technologies
# m/s ashok dyestuff private limited
# king cargo international
# compucover east pvt ltd
# brocade india polytex limited
# inox wind limited
# gautam puniani
# m/s apl apollo building products private limited
# sameer damodar punjabi
# m/s ri texsolutions private limited
# anish vinod agrawal
# charmie international
# m/s star exports
# m/s aakar engineers and consultants private limited
# pharmaexs ingredients private limited
# m/s jas polychem private limited
# arctic overseas private limited
# z and s group
# zed chem private limited
# cromsen importers
# shri hanish jindal
# gtx private limited
# durga polytherm pvt ltd
# m/s radha madhav inc
# m/s archit nuwood industries private limited
# furukawa sangyo kaisha india private limited
# m/s acg pam pharma technologies private limited
# tweza panels pvt ltd
# lrsa technology private limited
# dharamvir singh bisht
# shri vineet kumar
# biogenixcompostable private limited
# shri sunil grover
# sapana polyweave private limited
# satyam weldmesh industries
# shri kumar raj munjal
# virander behl
# mohd rafee mohd shafi patel
# prateek singh
# j p rice mill
# jotun india private limited
# m/s schneider electric india private limited
# itt corporation india private limited
# m/s fareast offshore heavy engineering private limited
# m/s rana poly green fila private limited
# ganesh maity
# m/s simran feeds private limited
# bajaj steel industries limited
# m/s macrotech developers limited
# dexgreen india private limited
# rehoboth enviro systems private limited
# smt neelam vadhera
# krunal shantilal gala
# skcc paper & board pvt ltd
# chirag metal
# outcome commercial private limited
# m/s craftsman automation limited
# m/s virchow petrochemical private limited
# inforob automation
# m/s bazinga media private limited
# umamaheswara rao kurapati
# upr engineering private limited
# kuber impex india
# m/s dsl solutions private limited
# cummins generator technologies india private limited
# galiakotwala engineering company pvt ltd
# ons impex traders private limited
# shri anuj gupta
# m/s micro life sciences private limited
# m/s sansui electronics private limited
# m/s mahansaria enterprises private limited
# usha gupta
# lite technology co. private limited
# decon india plastics private limited
# allflex india private limited
# shri deepak aggarwal
# m/s tirupur creations
# multiprene internationals pvt ltd
# m/s ammarun foundries
# m/s e con packaging private limited
# team seeds private limited
# octillion power systems india private limited
# rba ferro industries private limited
# sdr polymers private limited
# m/s ccty bearing india private limited
# centuary fibre plates pvt ltd
# dhiren chandulal shah
# d b international
# shree krishna food equipment and supplies private limited
# m/s dwarkadass chemical company private limited
# mitsui kinzoku components india private limited
# minal doshi
# m/s minda nabtesco automotive private limited
# m/s netro networks private limited
# m/s amama foods private limited
# bhagirathi packaging pvt ltd
# shri mukesh goel
# ikea india private limited
# rama panesar
# dynamic technology systems
# kaiair monitoring private limited
# smt bindu garg
# vibhuti entertainments private limited
# m/s storm infracon private limited
# smt anjali rastogi
# always fresh foods private limited
# m/s starline packers private limited
# ashish walecha
# m/s ensons infotech llp
# abdul gafoor iqbal qureshi
# shri nazim kasim mulla
# m/s emerson process management (india) private limited
# m/s geno pharmaceuticals private limited
# m/s madhav krg environmental solutions private limited
# m/s sterile india private limited
# shri dinesh atre
# shri thangamuthu saravanan
# mohammedibrahim basirahmed shaikh
# shri madanlal sanjay khanna
# m/s mukand limited
# m/s rajashree international manufacturing private limited
# mohit bansal
# hitachi astemo rajasthan brake systems
# m/s bigzero technology llp
# sage cosmetic llp
# muralidharan
# shree enterprises
# future ways inc
# m/s sogefi adm suspensions private limited
# foregen healthcare limited
# m/s modicon private limited
# prakash flexibles private limited
# m/s euro extrusions
# tanushri sanjiv gandhi
# ...
# m/s hallo foods private limited
# m/s m r m procom private limited
# chemoil advance technology
# shri shahabuddin ahmed khan
# m/s pitney bowes india private limited
# m/s raghav industrial products
# m/s unity gauge and tool co pvt ltd
# m/s amon ra impex pvt ltd
# shri vikas tiwari
# griffin semiconductors private limited
# m/s colossal hospitality and entertainment private limited
# navitas green solutions private limited
# icu medical india llp
# m/s sharika life science limited
# mayur gupta
# milkfood limited
# m/s c.r.auluck & sons private limited
# deon technology private limited
# shema e-vehicle & solar private limited
# goyam international
# anita nagpal
# hygiene plus limited
# m/s kalintis healthcare private limited
# rajiv kumar agarwal
# amrinder singh dhiman
# daiki axis environment private limited
# fosbel india private limited
# garden textiles private limited
# orson holdings co ltd
# shri gumanmal milapchand doshi
# m/s sadhana packaging private limited
# trasccon interconnection systems private limited
# m/s super nets & fabrics
# m/s pretty petals private limited
# m/s covestro (india) private limited
# shri ahmed shahbaaz khan
# m/s hemant surgical industries ltd
# shri pandurang ramnath bodke
# falguni sanjay busa
# furniture kraft international private limited
# auditivo hearing services private limited
# m/s saboo components and relays llp
# m/s denyo manufacturing india private limited
# panipat refinery and petrochemical complex, iocl
# uno mindarika private limited
# ellanti suneetha
# bysani amarnarayanagupta nagaraj
# sx pro private limited
# agarwal trafin private limited
# m/s chatur parmanand vaswani
# m/s prizm international
# foryour resque private limited
# taiba technoplast
# m/s pooja floor and furnishing private limited
# m/s frontier polymers privatelimited
# shree keshavkunj industries llp
# sunil bhupatrai desai
# m/s amazon wood private limited
# g amphray pharmaceuticals private limited
# shri prakash satya pareek
# smt pankaj smita vakharia
# surender kumar gupta
# indo count industries limited
# m/s electro devices private limited
# sahil mittal
# dcm shriram limited
# k. r. composites private limited
# ricasil industries
# m/s warp websters private limited
# balrampur chini mills ltd
# m/s clf transtrade india private limited
# shri balbir singh
# varsons fasteners pvt ltd
# m/s regal sports & playgroundequipment mfg co
# m/s zenex impex private limited
# shri mahendrabhai anand shah
# shri ram avadhoot zine
# vijay rosin & turpentine factory
# shri mashkoor alam
# harilal gurdasmal dalwani
# sanah mohammed aatique lohia
# power palazzo private limited
# vinod kumar jain
# salman abdul kader kolsawala
# arvind narayan solanki
# pkl enterprise
# avaada mhsustainable private limited
# gbc packaging
# weimar india llp
# rahul rathaur
# shri suumit jethwa
# zebion infotech private limited
# sangeeta khanna
# rasikbhai gokalbhai kardiya
# m/s adithya drug lines
# m/s balaji impex
# scott bader private limited
# rosy furniture private limited
# rexxam dixon electronics private limited
# royale resinex private limited
# arma products india private limited
# smt usha kalsi
# lifelong online retail private limited
# dux global solutions
# epsilon engineering pvt ltd
# aegis personal care llp
# goutam das
# m/s texeg india private limited
# yogesh sahlot
# archroma india pvt. ltd.
# vardhman yarns & threads ltd.
# bsb brokers llp
# m/s durga bondchem private limited
# suresh kumar chawla
# m/s shree balaji industries
# ashoka enterprises
# spack laminators pvt ltd
# s & h overseas
# paramount iron & steel works private limited
# arven texknit private limited
# shri juharmalji bharath kumar purohit
# kumari ahamad sulaiman shifana sulaiman
# indian overseas
# m/s gsk industries private limited
# chandra printing
# sks fasteners limited
# m/s spectrum international consultant
# vactech composites private limited
# nisha shailesh seth
# chimanlal girdharlal panchal
# xerox india limited
# jain homoeo pharmacy
# smk venture
# kraft heinz india private limited
# m/s k g petrochem ltd
# punch time impex
# rupal plastics private limited
# sanjay nayyar
# m/s shreeaadya merchandise private limited
# maya fertilizer and pesticide
# milan plast private limited
# cheryl laboratories pvt ltd
# ace tools
# m/s sri sainath industry private limited
# ard techtronics private limited
# m/s kmy business solutions and services llp
# m/s shubh overseas
# sandeep kumar
# m/s ekoson technology india private limited
# m/s adley formulations private limited
# trilok lasers
# castlerock fisheries privai ii limil l:l)
# shri jagdamba polymers li mited
# accurate polymers pvt ltd
# shri watinuksung jamir
# m/s skm overseas private limited
# anju chhawchharia
# m/s advance imaging solutions
# m/s uniform synthetics private limited
# m/s goyal stonex
# maharashtra soap works private limited
# m/s dabs packaging private limited
# m/s qlo networks private limited
# m/s knott vortex private limited
# bluemark technologies llp
# nita vijay kanekar
# m/s mti globex private limited
# polmann india limited
# deepak trading co.
# m/s okaya ev private limited
# m/s saitech instruments private limited
# smt satishkumar jayashree patil
# shri mahamadsalimbhai mahamadmohsin lakhani
# bibo biotech private limited
# m/s jvj exports
# m/s swaraj suiting limited
# shri hrithik pegoria
# smt anjali gupta
# glass wall systems (india) private limited
# r mavji co
# vigenindia mediquip private limited
# mirix automation
# m/s dns technologies private limited
# m/s body cupid private limited
# saini microelectronics private limited
# ananta polyrubb private limited
# shri kumar sumit gupta
# shri balvantrai vimal tolia
# india metpro products private limited
# coreflow chemi private limited
# page industries limited
# m/s elisa home appliances private limited
# trdp happy world pvt ltd
# sunil kumar bafna
# global agencies
# n n food impex
# m/s pac machine tools india llp
# m/s aurashine essentials private limited
# m/s glovetech safety india private limited
# vkm exports
# priyam garg
# mitsui & co. india private limited
# m/s symbiotec pharmalab pvt ltd
# m/s bottle bridge beverages llp
# ravindran
# m/s royaltern industries
# smt indu agarwal
# m/s rajiv nangalia (huf)
# kamal laxmi industries
# tupperware india pvt ltd
# jayantilal chunnilal doshi
# m/s mitil polymer private limited
# hirotec india private limited
# m/s evibloom private limited
# golchha enterprises private limited
# trident equipments private limited
# shri vijay chetan lale
# georg fischer piping systems private limited
# m/s g r infraprojects limited
# m/s tecumseh products india private limited
# atul kamdar
# krish impex
# eastea chai private limited
# go ip global services private limited
# shri hemant grover
# coko stores private limited
# darpan singh baweja
# richter themis medicare india pvt ltd
# hira walraven installations systems private limited
# kandoi fabrics private limited
# sagar dnyaneshwar gulhane
# green printing solution pvt ltd
# huliot pipes and fittings private limited
# electro aro automotive pvt ltd
# vcsmed india private limited
# narayan chemicals
# jeetendra kumar jain
# mining meadows india private limited
# m/s cronus pharma specialities india private limited
# jindal offset india private limited
# suman international
# paramjit singh chandock
# webasto roofsystems india private limited
# nayasa superplast
# shruti
# m/s panorama automotive industries private limited
# m/s bright metals india pvt ltd
# hankhul packwell pvt ltd
# millenium exim pvt ltd
# bhumika jain
# atibir hitech private limited
# millennium papier india pvt ltd
# tejender singh sabharwal
# ashvinkumar bhagvanbhai govinda
# sonu kumar
# rajeev rastogi
# ashok nanji patel
# sangeeta aggarwal
# m/s pankaj metals
# m/s sunflag iron & steel company limited
# sanjay commercial company
# sensa core medical instrumentation private limited
# mu plast private limited
# svp packing industry private limited
# m/s jamsfa solutions private limited
# wudlane traders llp
# m/s suvarchas solar power private limited
# hira lal devi sahai
# shri nitin katyal
# donaldson india filter systems private limited
# fortune medical devices llp
# a k i vaidyanath
# western refrigeration private limited
# shri sanjay jalan
# shri kumar anil sharma
# shri deepanshu
# udayan rameshchandra shah
# kapil ram motwani (huf)
# lumax ituran telematics private limited
# bhavna jayant goyal
# m/s tradelink computers private limited
# neowell lifetech private limited
# essemm specchem private limited
# ronak optik india private limited
# smt rinky devi
# the eimco kcp ltd
# rahul gulati
# m/s meril life sciences private limited
# viega india innovative technologies private limited
# satish damodar upadhyay
# sushil kumar surana huf
# satnam singh
# agarwal fastners pvt ltd
# solsys koncepts llp
# m/s gofab genesis llp
# stagemix technologies llp
# avon lifestyle private limited
# sukla sengupta
# m/s mst manufacturing solutions private limited
# m/s quality tissue converting company private limited
# panchsheel intermediates
# pearl drinks limited
# safe decor private limited (transfer from bihar to rajasthan)
# m/s shri sai pacwell private limited
# m/s hanuman graphics pvt ltd
# sham sunder & co
# bhupinder singh
# radhe enterprise
# bineeta bharat vaishnav
# m/s u.c connect services private limited
# ayaan import export private limited
# m/s rayden design studio private limited
# m/s ishnam impex private limited
# subhasri pigments private limited
# m/s galaxy tools private limited
# kothari hosiery factory pvt ltd
# pwr247 4u techsol private limited
# siddharth heavy industries private limited
# sarthak international
# ojus petrochemicals llp
# seabird ply-decor private limited
# m/s b r karwa nut and spices
# m/s trusted resources private limited
# m/s sheron furniture private limited
# rohit dutta
# r.p.tiles and tubes ltd.
# jiten agarwal
# shri janardhan ganesh kale
# k r industries
# m/s canpack india private limited
# m/s brightline thermoplast private limited
# elcome integrated systems private limited
# r r universal private limited
# mascot international private limited
# mfg overseas private limited
# m/s sn international
# krishnaping alloys limited
# m/s avaada mhgreen private limited
# monopol colors india private limited
# m/s badjate agro
# prime polychem private limited
# shri rajeev kapoor
# anil kapani
# g b enterprises private limited
# shree malani foams pvt ltd
# m/s century extrusions limited
# gs medical imaging private limited
# seema kapoor
# shri mansukhlal hitesh panchamiya
# m/s bonlon industries limited
# m/s choudhary fashions
# m/s fenda audio india private limited
# luminoso international private limited
# bhagavati parasmal jain
# rishabh incorporated
# wishbag online private limited
# s syed mohideen mukthar
# times lifestyle
# m/s virola international
# m/s arista worldwide exim llp
# purvraj agro industries private limited
# sugnomal sumit kukreja
# m/s orgo chem guj private limited
# smt shanta chandak
# sava healthcare limited
# sudheer kumar
# shri kuljeet wadhwa
# m/s kusa chemicals pvt ltd
# shri hari uday mahajan
# smt navneet kaur
# ashirwad agro
# agri wing organics
# rare earth brands llp
# m/s skyexim industries company
# m/s mm musical llp
# dev vrat rana
# amneal injectables private limited
# empress creation
# shri gumanmal ghevarchand doshi
# calcutta export company
# umang arvindkumar bafna
# m/s envee drugs pvt ltd
# flow p&e india private limited
# m/s radix electro systems pvtltd
# mat foundry india private limited
# m/s akhil bhuwan agro industries
# chemexcil corporation
# saad sayyed abdul aziz
# vikram roopchand mehta
# shri jitender kumar
# shilpa international
# m/s amtech esters private limited
# samir ashokbhai pachal
# ashish nitin mehta huf
# m/s papa music
# m/s vishvarupa solar power private limited
# m/s tianyin worldtech india private limited
# m/s vedang radio technology private limited
# jeoo prakash panjwani
# m/s maheshkumar b jogani huf
# m/s narayani technocontainers
# m/s agrawal rajkumar chandrabhan (huf)
# shree shyam enterprises
# mehul vijaykumar gupta
# grefuel private limited
# golden valley
# m/s loretta industries
# m/s sis alarm monitoring and response services private limited
# ashwath inc
# m/s universal additives
# m/s dusmer tools pvt ltd
# m/s advance catalyst private limited
# tfb exim (india) private limited
# shri chandprakash dhiraj asopa
# kirloskar ferrous industries ltd
# agarwal toughened glass india private limited
# hollister medical india private limited
# optimas oe solutions india private limited
# m/s chungath agencies
# honesty developers private limited
# asian tradelinks private limited
# ashish kumar ohri
# m/s leoxsys networks private limited
# m/s nikkei cmr aluminium india private limited
# bilwamongal singharoy
# m/s vedika exports tea private limited
# dongyang electric and power india private limited
# m/s shamcor international logistics private limited
# m/s khaitan mercantile limited
# swastik tins private limited
# shri chandiram jagdish motwani
# shri ajoy modi
# g.d.foods manufacturing (india) private limited
# musk products
# ehsan agro wood products private limited
# rajdeep energies private limited
# atlas metal processors pvt ltd
# hil limited
# hertz chemicals private limited
# m/s chalet hotels limited
# prashant polykraft p limited
# b. r. collection
# shri radhakrishan sandeep singla
# kamalesh jain
# shri sunder shyam arora
# m/s shree parth timber private limited
# bonifatius technologies private limited
# m/s vena energy vidyuth private limited
# octane powersports llp
# m/s zeron enterprises
# shri gopal dass
# stryker india pvt ltd
# morex composites private limited
# m/s hexagon metrology india private limited
# m/s fibtex products
# connector devices
# smt anu kalra
# duschell plast
# m/s expo world enterprises
# new shriyansh enterprises
# m/s gulshan polyols limited
# m/s bagla polifilms limited
# shiv electronics
# m/s para products private limited
# tirumala milk products private limited
# m/s polymorphic systems private limited
# panther petroleums private limited
# james sekar
# vishal kataria
# surya nonwovens private limited
# rahul singh
# hakimuddin bhemat
# krannich solar private limited
# raj kumar agarwal
# m/s perkins india private limited
# m/s leatherman fashion private limited
# m/s dolphin life science india llp
# shri arun kundan mhaskar
# lazy soul cosmetics llp
# m/s associated packaging machines private limited
# santosh chhaganlal kabra
# m/s sas automation private limited
# manishaben ashvinbhai kheni
# m/s polymet films private limited
# m/s apl apollo tubes limited
# eicher goodearth private limited
# prakhar gupta
# infinity solutions
# heritage novandie foods private limited
# patel agrotech private limited
# suriya impex
# swapan das
# devdarshan overseas
# oswal industries limited
# m/s elecon engineering company limited
# tata motors body solutions limited
# marelli um electronic systems private limited
# sanghavi mitesh himatlal huf
# shri navin sehgal
# santosh koparam
# m/s barak valley cements limited
# vikas goel
# m/s chromaflo technologies india private limited
# chetan adarshveer jain
# sumfonl auto traders private limited
# absr engineers & services private limited
# balwant singh namdhari
# m/s suraj moulders (pvt) ltd.
# shri rajesh khattry
# parveen iqbal memon
# sumit sarin
# m/s yasho industries limited
# nathiben joitaram patel
# shri noman adil siddiqui
# m/s quadronix systech technologies private limited
# shri gopalbhai pareshkumar goti
# macer industries private limited
# m/s quality systems and equipments private limited
# ramandeep kaur bajwa
# m/s sharda patterns
# dermacare surgicals private limited
# m/s pixcom systems private limited
# party shop
# jindba processors private limited
# m/s eleind engg p ltd
# suruga india private limited
# sulochna retail mart private limited
# m/s arihant safe glass private limited
# the party collective
# hydropure systems private limited
# sri r & m impex
# shri himanshu vyas
# m/s micasa international
# hindustan pencils private limited
# shravan laxmichand suthar
# mangla overseas
# ecaps computers india private limited
# jagdish bhanji manjeri
# prem chand tapen
# shiv shankar tiwari
# flexible hose industries
# lewens labs private limited
# shri jayant purbi
# m/s r b agro milling private limited
# mohammed amaan masood ahmed sayyed
# vitality hair india private limited
# m/s palram india private limited
# vidya jawahar soneji
# m/s prince enterprise
# m/s sun pharmaceutical industries limited
# vijaykumar kanubhai thakkar
# shri ramji mahesh bera
# kanad chemicals private limited
# m/s voith paper technology (india) private limited
# krish international
# nikhil ramanlal oswal
# agromac industries
# neera bhima sahakari sakhar karkhana ltd
# sarwar food products private limited
# shirdi panel industries limited
# asiczen technologies india private limited
# m/s usana health sciences india private limited
# m/s amit capacitors limited

# %%
import pandas as pd
import re

def clean_company_name(name):
    """
    Clean the company name by removing any address or extra details after the first comma.
    Assumes that the company name is the first part of the string before any commas or line breaks.
    
    Parameters:
    - name: The raw company name and address string
    
    Returns:
    - Cleaned company name
    """
    if pd.isna(name):
        return ""
    # Remove everything after the first comma (assuming the name comes before the comma)
    cleaned_name = name.split(',')[0]
    # Optionally, you can add further processing to remove unwanted characters, like newline characters
    return cleaned_name.strip()

def extract_and_clean_name_column(file_path, output_file):
    """
    Extract and clean the 'Name & Address' columns and save the cleaned company names to a new CSV.
    
    Parameters:
    - file_path: Path to the input CSV file
    - output_file: Path to save the cleaned output CSV file
    """
    try:
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Columns to clean
        name_columns = ['Name & Address', 'NAME & ADDRESS', 'Name']
        
        # Check if any of the columns exist
        for col in name_columns:
            if col in df.columns:
                # Clean the data in the column
                df[col] = df[col].apply(clean_company_name)
        
        # Save the cleaned company names to the output CSV
        df.to_csv(output_file, index=False)
        print(f"Cleaned data saved to: {output_file}")
    
    except Exception as e:
        print(f"Error: {e}")

# Example usage
input_file = 'merged_output_1.csv'  # Replace with your input CSV file path
output_file = 'cleaned_output.csv'  # Path to save the cleaned output CSV file

extract_and_clean_name_column(input_file, output_file)
# Out:
# Cleaned data saved to: cleaned_output.csv

# %%
import pandas as pd
import re

def clean_company_name(name):
    """
    Clean the company name by removing any address or extra details after the first comma or keywords like 'Plot No', 'Survey No', etc.
    
    Parameters:
    - name: The raw company name and address string
    
    Returns:
    - Cleaned company name
    """
    if pd.isna(name):
        return ""
    
    # Remove text starting from 'Plot No', 'Survey No', 'Gat No', or any commas
    name = re.sub(r'[,|.].*', '', name)  # Remove everything after the first comma or period
    name = re.sub(r'Plot No.*', '', name)  # Remove anything after 'Plot No'
    name = re.sub(r'Survey No.*', '', name)  # Remove anything after 'Survey No'
    name = re.sub(r'Gat No.*', '', name)  # Remove anything after 'Gat No'
    
    # Clean up any extra spaces and return the cleaned name
    return name.strip()

def merge_and_clean_name_columns(input_file, output_file):
    """
    Merge the 'Name & Address', 'NAME & ADDRESS', 'Name' columns into one 'Name' column
    and clean the company names by removing any address or extra details.
    
    Parameters:
    - input_file: Path to the input CSV file
    - output_file: Path to save the cleaned output CSV file
    """
    try:
        # Read the CSV file
        df = pd.read_csv(input_file)
        
        # Columns to merge
        name_columns = ['Name & Address', 'NAME & ADDRESS', 'Name']
        
        # Merge the columns into one 'Name' column by prioritizing non-null values
        df['Name'] = df[name_columns].apply(lambda row: next((x for x in row if pd.notna(x)), ""), axis=1)
        
        # Clean the 'Name' column by removing addresses or extra details
        df['Name'] = df['Name'].apply(clean_company_name)
        
        # Optionally, drop the original columns if not needed
        df.drop(columns=name_columns, inplace=True)
        
        # Save the cleaned data with merged 'Name' column to a new CSV file
        df.to_csv(output_file, index=False)
        print(f"Cleaned and merged data saved to: {output_file}")
    
    except Exception as e:
        print(f"Error: {e}")

# Example usage
input_file = 'cleaned_output.csv'  # Replace with your input CSV file path
output_file = 'cleaned_merged_output.csv'  # Path to save the cleaned and merged output CSV file

merge_and_clean_name_columns(input_file, output_file)
# Out:
# Cleaned and merged data saved to: cleaned_merged_output.csv

# %%
import pandas as pd

def compare_csv_files(file1_path, file2_path, column_name='Name', output_file='comparison_result.csv'):
    """
    Compare two CSV files and save names that are in one file but not in the other into a CSV file.
    
    Parameters:
    - file1_path: Path to the first CSV file
    - file2_path: Path to the second CSV file
    - column_name: The name of the column to compare (default is 'Name')
    - output_file: The path to save the comparison results (default is 'comparison_result.csv')
    """
    try:
        # Read the CSV files into DataFrames
        df1 = pd.read_csv(file1_path)
        df2 = pd.read_csv(file2_path)

        # Check if the column exists in both files
        if column_name not in df1.columns or column_name not in df2.columns:
            print(f"Column '{column_name}' not found in one of the files.")
            return
        
        # Extract the 'Name' column and drop any NaN values
        names_file1 = set(df1[column_name].dropna().str.strip().str.lower())  # Normalize to lower case
        names_file2 = set(df2[column_name].dropna().str.strip().str.lower())  # Normalize to lower case

        # Compare and find names that are in file1 but not in file2, and vice versa
        unique_to_file1 = names_file1 - names_file2
        unique_to_file2 = names_file2 - names_file1

        # Convert sets to lists
        unique_to_file1 = list(unique_to_file1)
        unique_to_file2 = list(unique_to_file2)

        # Adjust the lengths of both lists by padding the shorter one with None
        max_length = max(len(unique_to_file1), len(unique_to_file2))
        unique_to_file1.extend([None] * (max_length - len(unique_to_file1)))  # Pad with None
        unique_to_file2.extend([None] * (max_length - len(unique_to_file2)))  # Pad with None

        # Prepare the result DataFrame
        result_data = {
            'Names in File1 but not in File2': unique_to_file1
        }

        result_df = pd.DataFrame(result_data)

        # Save the results into a CSV file
        result_df.to_csv(output_file, index=False)
        print(f"Comparison results saved to {output_file}")

    except Exception as e:
        print(f"Error: {e}")

# Example usage
file1_path = 'Mpcb_companies.csv'  # Path to the first CSV file
file2_path = 'Cpcb_companies.csv'  # Path to the second CSV file
output_file = 'comparison_result.csv'  # Output file path

compare_csv_files(file1_path, file2_path, output_file=output_file)
# Out:
# Comparison results saved to comparison_result.csv
