# %%
# %pip  install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python312\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import pandas as pd

def extract_column_to_csv(csv_file_path, column_name, output_csv_path):
    """
    Extract a specific column from a CSV file and save it as a CSV file.
    
    Parameters:
    - csv_file_path: Path to the CSV file
    - column_name: The name of the column to extract
    - output_csv_path: Path to save the extracted column as a CSV file
    """
    try:
        # Read the CSV file
        sheet_data = pd.read_csv(csv_file_path)
        
        # Check if the column exists in the sheet
        if column_name in sheet_data.columns:
            # Extract the column and save it to CSV
            sheet_data[[column_name]].dropna().to_csv(output_csv_path, index=False)
            print(f"Column '{column_name}' has been successfully extracted to CSV.")
        else:
            print(f"Column '{column_name}' not found in the CSV file.")
    except Exception as e:
        print(f"Error: {e}")

# Example usage with absolute path
csv_file_path = r'Mpcb_file/MPCB Electronic Waste.csv'  # Adjust with the correct path
column_name = 'Name & Address'  # Replace with the column name you want to extract
output_csv_path = 'output_file.csv'  # Path to save the output CSV file

extract_column_to_csv(csv_file_path, column_name, output_csv_path)
# Out:
# Column 'Company Name' has been successfully extracted to CSV.

# %%
import pandas as pd

def print_column_names_from_second_row(csv_file_path):
    """
    Print column names from the second row of a CSV file.
    
    Parameters:
    - csv_file_path: Path to the CSV file
    """
    try:
        # Read the CSV file and use the second row as the column names
        data = pd.read_csv(csv_file_path, header=1)
        
        # Print the column names
        print("Column names from the second row:")
        for column in data.columns:
            print(column)
    except Exception as e:
        print(f"Error: {e}")

# Example usage with absolute path
csv_file_path = r'Mpcb_file/MPCB Electronic Waste.csv'  # Adjust with the correct path

print_column_names_from_second_row(csv_file_path)
# Out:
# Column names from the second row:
# Sr. No.
# Name and Address of Industry
# Regional Office
# Type
# Capacity Allotted as per
#  Consent / Authorisation (MT/A)
# Consent / Authorization No. & Issue Date
# Validity of
#  Consent / Authorization
# E-mail Address
# Contact Number
# Current Status

# %%
import pandas as pd

def extract_column_to_csv_from_second_row(csv_file_path, column_name, new_column_name, output_csv_path):
    """
    Extract a specific column from the second row of a CSV file, rename it, and save it as a CSV file.
    
    Parameters:
    - csv_file_path: Path to the CSV file
    - column_name: The name of the column to extract
    - new_column_name: The new name for the extracted column
    - output_csv_path: Path to save the extracted column as a CSV file
    """
    try:
        # Read the CSV file and use the second row as column names
        sheet_data = pd.read_csv(csv_file_path, header=1)
        
        # Check if the column exists in the sheet
        if column_name in sheet_data.columns:
            # Extract the column, rename it, and save it to CSV
            extracted_column = sheet_data[[column_name]].dropna()
            extracted_column.columns = [new_column_name]
            extracted_column.to_csv(output_csv_path, index=False)
            print(f"Column '{column_name}' from the second row has been successfully extracted and renamed to '{new_column_name}' in the CSV file.")
        else:
            print(f"Column '{column_name}' not found in the CSV file.")
    except Exception as e:
        print(f"Error: {e}")

# Example usage with absolute path
csv_file_path = r'Mpcb_file/MPCB Electronic Waste.csv'  # Adjust with the correct path
column_name = 'Name and Address of Industry'  # Replace with the column name you want to extract
new_column_name = 'Company Name'  # New name for the extracted column
output_csv_path = 'output_file.csv'  # Path to save the output CSV file

extract_column_to_csv_from_second_row(csv_file_path, column_name, new_column_name, output_csv_path)
# Out:
# Column 'Name and Address of Industry' from the second row has been successfully extracted and renamed to 'Company Name' in the CSV file.

# %%
import re
import csv

# File paths
input_file = "output_file.csv"  # Replace with your input file name
output_file = "company_names.csv"  # Output file name

# Read the input CSV file
with open(input_file, "r", newline='', encoding="utf-8") as infile:
    reader = csv.reader(infile)
    data = [row[0] for row in reader]  # Assuming company details are in the first column

# Regular expression to extract company names
company_names = [re.match(r"^[^,]+", row).group(0) for row in data if re.match(r"^[^,]+", row)]

# Save the cleaned company names into a new CSV file
with open(output_file, "w", newline='', encoding="utf-8") as outfile:
    writer = csv.writer(outfile)
   # writer.writerow(["Company Name"])  # Header row
    for name in company_names:
        writer.writerow([name])

print(f"Cleaned company names saved to {output_file}")
# Out:
# Cleaned company names saved to company_names.csv

# %%
#mergeing two csv files
import os
import pandas as pd

def merge_csv_files(input_folder, output_file, column_name='Company Name'):
    """
    Merge all CSV files from a specified folder into a single CSV file with one column named 'Name'.
    
    Parameters:
    - input_folder: Path to the folder containing the CSV files
    - output_file: Path to save the merged CSV file
    - column_name: The name of the column to extract (default is 'Name')
    """
    try:
        # List to hold all the company names under 'Name' column
        all_data = []

        # Loop through all files in the specified folder
        for file in os.listdir(input_folder):
            if file.endswith('.csv'):
                file_path = os.path.join(input_folder, file)
                # Read each CSV file
                data = pd.read_csv(file_path)
                
                # Ensure the 'column_name' exists in the CSV, then extract the data
                if column_name in data.columns:
                    all_data.extend(data[column_name].dropna().tolist())  # Add the data to the list

        # Create a DataFrame from the list of all data
        merged_data = pd.DataFrame({column_name: all_data})

        # Save the merged DataFrame to a new CSV file
        merged_data.to_csv(output_file, index=False)
        print(f"Merged CSV file saved at: {output_file}")

    except Exception as e:
        print(f"Error: {e}")

# Example usage
input_folder = r'cpcb_companies'  # Replace with the folder containing your CSV files
output_file = 'cpcb_companynames.csv'  # Path to save the merged CSV file

merge_csv_files(input_folder, output_file)
# Out:
# Merged CSV file saved at: output_file.csv

# %%
import pandas as pd

def compare_csv_files(file1_path, file2_path, column_name='Company Name', output_file='comparison_result.csv'):
    """
    Compare two CSV files and print names that are in one file but not in the other.
    
    Parameters:
    - file1_path: Path to the first CSV file
    - file2_path: Path to the second CSV file
    - column_name: The name of the column to compare (default is 'Company Name')
    """
    
    try:
        # Read the CSV files into DataFrames
        df1 = pd.read_csv(file1_path)
        df2 = pd.read_csv(file2_path)

        # Check if the column exists in both files
        if column_name not in df1.columns or column_name not in df2.columns:
            print(f"Column '{column_name}' not found in one of the files.")
            return
        
        # Extract the 'Company Name' column and drop any NaN values
        names_file1 = set(df1[column_name].dropna().str.strip().str.lower())  # Normalize to lower case
        names_file2 = set(df2[column_name].dropna().str.strip().str.lower())  # Normalize to lower case

        # Compare and find names that are in file1 but not in file2
        unique_to_file1 = names_file1 - names_file2
        unique_to_file2 = names_file2 - names_file1
        
        # Print the results
        if unique_to_file1:
            print(f"Names in {file1_path} but not in {file2_path}:")
            print("\n".join(unique_to_file1))
        else:
            print(f"No names found in {file1_path} but not in {file2_path}.")

        if unique_to_file2:
            print(f"\nNames in {file2_path} but not in {file1_path}:")
            print("\n".join(unique_to_file2))
        else:
            print(f"No names found in {file2_path} but not in {file1_path}.")

        # Prepare the result DataFrame
        result_data = {
            'Company Names in Mpcb but not in cpcb': list(unique_to_file1)
        }

        result_df = pd.DataFrame(result_data)

        # Save the results into a CSV file
        result_df.to_csv(output_file, index=False)
        print(f"Comparison results saved to {output_file}")

    except Exception as e:
        print(f"Error: {e}")

# Example usage
file1_path = r'mpcb_companies/mpcbcompany_names.csv'  # Path to the first CSV file
file2_path = r'cpcb_companynames.csv'  # Path to the second CSV file
output_file = 'comparison_result.csv'  # Output file path

compare_csv_files(file1_path, file2_path)
# Out:
# Names in mpcb_companies/mpcbcompany_names.csv but not in cpcb_companynames.csv:
# hari om scrap traders
# e clean e green recycling
# earth sense recycle pvt. ltd.
# kapila enterprises
# rolex entrprises
# national sales corporation
# e-recon recycling pvt. ltd.
# ecolayer e-waste recycling
# connect info solutions india private limited
# sahara traders
# green valley e-waste management pvt. ltd.
# mukesh metal
# mercury metal industries (unit iii)
# ancus india reprocessing pvt. ltd.
# rcube recycling pvt ltd.
# alfa trading co.
# aman trading co. f/1
# perfect e-waste recyclers
# biyani polymers
# imagine marketing limited
# bhangarwala waste management pvt ltd.
# sultan disposal stores
# comnet e-waste llp
# green enviro management
#  solutions llp
# process recycling
# recycling future
# jupiter enterprises
# bombay scrap traders
# d trading company
# pune green electronic waste recycler pvt. ltd.
# green it recycling centre pvt. ltd.
# green valley e waste management pvt ltd
# grade infratech pvt. ltd.
# anand computer system
# e cycle & company
# suritex pvt. ltd.
# a k barrels and generals scrap
# eco layer e-waste recycling
# manish metal
# bhavesh enterprises
# bke recycling
# k. g. n. traders
# general technologies india pvt ltd
# sayma e-waste solutions
# clean e-waste recycling
# aman steel enterprises
# e-waste mart
# asquare industrial solutions
# reteck envirotech pvt. ltd.
# trans thane creek waste
#  management association
#  p-128
# big bull recyclers private limited
# manihar enterprises
# raj enterprises
# ambar enterprises
# diamond machinery tools
# we-the recycling company
# global e-recycling pvt ltd.
# rajmudra trading
# the2bros
# vatsala enterprises
# om r v interiors
# e-incarnation recycling pvt. ltd. plot no. j-56
# somnath industries pvt ltd..
#  os-56
# om recycling
# s. s. e-waste recyclers
# electrofine recycling (opc) private limited
# solapur econ recyfine
# star envo recycling (i) private limited
# jai ambe enterprises
# kalawishwa electrical
# valji khimji & co.
# justdispose recycling pvt ltd. (unit- ii)
# naaz trading company
#  gat no. 66
# v k metal corporation gut no. 433 part
# new india scrap traders
# j. s. enterprises
# s. n. brothers
# gnr recycling india pvt ltd
# a. s. enterprises
# new india recyclers
#  plot no. 5 & 6
# muskmelon envtech pvt. ltd. godown d-4
# naved enterprises
# r t corporation
# avis technoways
# green enviro services
# m. s. malik
# lico materials pvt ltd
# clean tech
# environment experts
# s.k. enterprises
# dev it serv pvt ltd
# poona e-waste solutions
# mauli metals
# amiable electroning pvt. ltd.
# envirocare recycling pvt. ltd.
# mac fix station
# tarai projects pvt. ltd.
# z a barrel suppliers
# progressive recycler llp. midc
#  chakan industrial area (ph-ii)
# sigma enterprises
# nasib scrap centre
# indian scrap traders
# erecon recycling pvt. ltd.
# sahara enterprises
# royal scrap traders
# new ecotech recycling
# e-frontline recycling pvt. ltd. gat no. 183/1
# zakiya amin enterprises
# green planet recycling solutions
# chaudhary metal. 80/2
# aman e-waste disposal
# hi-tech recycling (i) pvt. ltd
# j choudhary & company
# lucky enterprises
# kuldeep e-waste disposals
# mahalaxmi e- recyclers pvt. ltd. plot no.77 & 78
# sai enterprises
# new shivam enteprises
# vora computers pvt. ltd.
# harshita green recyclers
# aman e-waste recyclers pvt ltd.
# r.k.e-recycling international llp gala no.-2
# ask steel
# right e-waste recycle
# amin industries
# ag enterprises
# unity enterprises
# bombay metal works
# clean planet llp
# wave e waste recycling pvt ltd. sr. no. 11
# sk e-waste disposal
# afton e-waste recycling
# green it recycling center pvt ltd
# maharashtra enterprises plot no.d-49/2
# lilashana sales
# kuldeep green recyclers private limited
# arihant e recycling pvt ltd
# shree recyclers
# rajhans ferrous scrap trade private limited
# gng electronics pvt. ltd.
# nagraj e-waste recycling
# green clean recycling
# anitha sri recycling
# e-refine corporation
# shifa traders
# nizam enterprises
# saani enterprises
# nicholas recycling private
#  limited
# lexim international pvt. ltd.
#  plot no. d-192
# baban plastic
# trekomac refurbs pvt. ltd.
# regreen recycling
# map trading company
# go green recycling
# navkar recycling
# e-survival recycling private limited
# eco-recycling ltd.
# pakeeza traders
# evergreen recyclekaro india pvt.
#  ltd.
# savita barrels
# kesariya metal conrporation
# saraswati enterprises
# green india e-waste & recycling opc pvt. ltd.
# techeco e-waste namo llp
# bakruddin din mohammad
# bsqaure e-waste recyclers
# cbs e-waste recycling industries
# noble trading company
# avis group
# jeenali trading & comm. serv. pvt. ltd.
# mayra corporation
# spas computers pvt. ltd. 7 & 12
# eco tantra llp
# bhagyalakshmi laboratories limited
# kohinoor e-waste recycling pvt. ltd. gut no. 205/1 and 205/2
# yasin scrap
# bombay recyclers pvt. ltd.
# bharat e waste recycling co.
# jrs recycling solutions pvt. ltd. gala no. 428
# cpg shell mould & casting
# deshwal waste management pvt.
#  ltd.
# binbay recycling pvt. ltd.
# shuaib traders
# haq processing pvt. ltd.
# national traders
#
# Names in cpcb_companynames.csv but not in mpcb_companies/mpcbcompany_names.csv:
# urban metals
# green vision recyclers private limited
# global waste solution
# dustman waste management & recycling pvt
# epsilon circular infrastructure private limited
# green enviro e waste recycling
# techchef ewaste solutions private limited
# m/s bhagyalakshmi laboratories limited
# m/s e-waste recyclers india
# shivalik solid waste management limited unit-2
# suritex private limited
# kh e waste recyclers
# anviani sustainable recycling llp
# brp infotech private limited
# m a k technology industrial
# terranova eco management private limited
# safdar e recycling private limited
# victory recovery recycle technologies india private limited
# sas tech e waste recycling solutions
# exigo recycling private limited
# saisriwastemanagementpvtltd
# bombay recyclers private limited
# bhanu metal industries
# s n sustainable resources private limited
# i d technocom
# green web recycling
# envirokare recycling solutions pvt. limited
# e box recyclers
# greenify waste solutions private limited
# greenglobal recycling privatelimited
# e tree technologies
# attero recycling private limited
# ozone waste llp
# m/s. e-parisara pvt.ltd,
# jeenali trading & comm. ser. pvt. ltd.
# endeavor recyclers india private limited
# evergreen e waste management pvt ltd
# electro waste solutions
# viable e-waste recycler private limited
# edhini recycling private limited
# 4r recycling pvt ltd
# proplanet recyclers llp
# e scrappy recyclers
# m/s root recycling
# mega recycling private limited
# 3r recycler
# thapar disposal industries
# virogreen india private limited
# arp recycling private limited
# sheeltron digital systems private limited
# wastetech recycling company
# ecotime industries
# ka e-waste solution llp
# moogambigai metal refineries
# unicare e waste recycler
# shukla e-waste processor
# waste recycling studio
# riot labz private limited
# star recycling
# green bird recycling
# ortech india corporation
# new india sales corporation
# greens recology company
# ganpati scraps
# gnr recycling india private limited
# greenwish e waste recyclers
# jsa web solutions
# green nexus recyclers private limited
# justdispose recycling pvt ltd
# ishvarya traders
# ads recycling private limited
# evergreen recyclekaro india private limited
# circularity solutions private limited
# pruthvi e-recycle pvt.ltd
# techazar e-cyclers private limited
# bsquere ewaste recyclers
# anjani ewaste recycling
# etco e-waste recycler private limited
# siddhavi tech
# j s pigments pvt ltd
# haq processing private limited
# reart recycling private limited
# cerebra integrated technologies ltd
# go green managment llp
# massrr e-neermalya
# hi-tech recycling india pvt ltd
# egreen dust
# exigo recycling pvt ltd
# brp infotech pvt ltd
# global tech recyclers
# greenlink recyclers private limited
# wipro ge healthcare pvt. ltd
# m/s simran infotech
# malapani antenna electronics ltd
# trivendent technologies pvt ltd (zolopik
# envirocare recycling private limited
# hindusthan recycling
# prakash metal house
# meliorate lubes pvt ltd
# m/s. jrs recycling solutions pvt. ltd
# greenzon recycling pvt ltd
# taj computer solutions private limited
# ecoverva ewaste recycling pvt ltd
# sky green waste recycling management
# eco trend recyclers
# adv metal combine pvt. ltd.
# trishyiraya recycling india private limited
# e waste solutions
# eco works management pvt ltd
# hitech eco green
# comnet e waste llp
# muzashi recyclers private limited
# sogo synergy private limited
# f1 info solutions & services private limited
# global e-recycling private limited
# gl recycling llp
# coral communications and networks p ltd
# green valley ewaste management private limited
# mkk e waste recyclers
# smash recycler private limited
# shiv shakti metals
# etco ewaste recycler private limited
# matrix info systems private limited
# greensense waste recycling management private limited
# hin green e-waste recycling private limited
# global traders
# marss recycler pvt. ltd
# eco globe e waste recyclers
# b.s.m.r metals
# prakruthi recycling pvt ltd
# ramky arm recycling private limited
# re-chakra waste management llp
# green india e-waste & recycling opc pvt ltd
# renavart recyclers india private limited
# re sustainability reldan refining private limited
# greenlet recycler private limited
# binbay recycling private limited
# kohinoor e waste recycling pvt ltd
# ever green ewaste recycling management
# rajdhani recycling private limited
# adinath recyclotronix private limited
# pegasus environment llp
# elxion pvt ltd unit2
# rbh e-waste recycle hub pvt ltd
# rolex enterprises
# soriaan recyclers private limited
# z enviro industries pvt. ltd.
# bhangarwala waste management pvt ltd
# rk enterprises
# aman e waste recyclers pvt ltd
# s k e waste disposal
# anmol paryavaran sanrakshan samiti
# resource e waste solutions private limited
# green world recyclers
# liberty recycling
# royal e waste recycling co
# greentek reman private limited
# recyclico waste management
# think recycling private limited
# saahas waste management pvt. ltd
# manak waste management private limited
# global metalists private limited
# recycling villa
# epragathi recycle private limited
# ush india recycler pvt ltd
# sonal metacop
# greenview e waste recycling
# ry recyclers
# pune ok greens electronic waste recycler private limited
# green era recyclers
# e-frontline recycling pvt ltd
# black diamond cements private limited
# grandeur recycling private limited
# deshwal waste management pvt. ltd
# a k m recyclers
# yaantra
# cosmos recycling private limited
# tes-amm (india) private limited
# e-friendly waste recyclers
# florus recycling private limited
# pythonic waste services private limited
# green it recycling centre pvt ltd
# eco fly ewaste recycling pvt. ltd
# hi tech scrap processors
# vivo mobile india pvt ltd
# taruna e-waste industries
# m/s pranam enterproses
# npewaste pvt ltd
# spreco recycling
# star e processors
# green vortex waste management private limited
# bharat oil company (i) regd.
# gracy eco traders
# ms 2nds computers
# envitech recycling private limited
# trans thane creek waste management association
# sriram eco raksha computer service private limited
# eco green recycling
# foxx compliance services private limited
# m/s kesariya metal corporation
# bright e waste recycling india
# payas recyclers
# globe ewaste management
# krv solar
# weee-pro resource recovery solutions private limited
# mahaarana industries private limited
# shri raam recycling
# horizon recycling pvt ltd
# a k barrels
# sahyasolutions group of waste management
# grkms pvt ltd
# vans chemistry pvt ltd
# c s mitra e-waste management
# e-waste recyclers india
# ezwaste recycling
# my return solutions private limited
# elxion private limited
# gujarat green recycling
# shreeram e waste recyclers and traders
# rke recycling international llp
# greenscape eco management pvt ltd
# epragathi recycing
# scope recycling private limited
# p u steel & electro process private limited
# egnus ewaste solutions private limited
# mahalaxmi metalloys india pvtltd
# purus e waste recyclers private limited
# laxminarayana recyclers llp
# m/s. e-parisaraa pvt. ltd.
# fiz trading company
# dron e waste solution
# wb e waste control management pvt ltd
# pegasus waste management pvt ltd
# e-clean e-green recycling
# e cycle solutions private limited
# primero recycling private limited
# mothiya brothers
# sachin enterprises
# fs india solar ventures private limited
# weee pro resource recovery solutions private limited
# ecolayer e waste recycling
# zasha electrowaste recycling pvt ltd
# attero recycling pvt. ltd
# ms lalit industries
# grade infratech pvt ltd
# axom refurbisher
# sara recycling
# poona e waste solutions
# green india recyclers
# new friends waste management
# deshwal waste management pvt. ltd.
# rescalex
# m/s meher waste solutions
# e2e recycling business private limited
# inclusive recycling foundation
# nirvana recycling pvt ltd
# shiwshakti metal works
# spc international (india) private limited
# e tech e waste recycling
# namo ewaste management limited
# glacier enviro india pvt ltd
# e incarnation recycling pvt ltd
# sungeel india recycling pvt ltd
# best e-waste recyclers private limited
# sayma ewaste solutions
# justdispose recycling pvt.ltd
# privi speciality chemicals limited
# hcas resources private limited
# er3 solutions private limited
# k.j. recyclers
# arihant e recycling private limited
# beil infrastructure limited
# i seven
# adatte e-waste management pvt. ltd
# green pc world private limited
# gogreen recycling
# hal solution private limited
# electrofine recycling opc pvt ltd
# nature eco building private limited
# soni recycle compaby
# recfly recyclers private limited
# ecotantra llp
# nagraj ewaste recycling
# arlington information systems pvt ltd
# recology recycling india private limited
# pure earth recyclers private limited
# green clean recyclers llp
# ramdass trading company
# limr recycling private limited
# eco vita recycling llp
# circularity solutions pvt ltd, nashik
# elgreen recycling private limited
# swachh bharat recycling company
# m/s shabbir traders
# s n brothers
# universal power solutions
# spreco resource recyclers
# reboot resources private limited
# mobitech e-waste recycler -run by-mobitech llp
# cynosure recycling private limited
# global copper pvt ltd
# infinity green e recycling solutions
# ecoverva e waste recycling private limit
# sk enterprises
# abaad developers private limited
# urban edge environment private limited
# e survival recycling private limited
# anubahv e-waste recycler india llp
# enviropro sustainability private limited
# 3r recycler private limited
# trader traders
# india best way recycling
# green roots waste management pvt ltd
# hme waste management
# carbios eco waste management private
# unique eco recycle
# p and y bhavya recyclers private limited
# earth sense recycle private limited
# exstrat
# global waste solution unit-ii
# clean india recycling pvt ltd
# royal faiz recycling private limited
# navkar recycling private limited
# waste pro recycling
# tes amm (india) pvt ltd
# tharani electronics waste
# new india recyclers
# cynosure recycling private limited-unit ii(hyd
# elifecycle management pvt ltd
# green wave e waste recycling
# aireco recyclers private limited
# anand computer systems
# eali recyclers
# sri balaji
# e-waste recyclers india (unit 3)
# evergreen e-waste management private ltd
# eco saviour e waste management pvt. ltd.
# naturevolt recyclers india pvt ltd
# ecoverva e-waste recycling private limited
# kalpana e recycler
# e-pragathi recycling
# sez recycling
# vorgoo recycling private limited
# greencube recycling private limited
# gauvins green management private limited
# prometheus recycling private limited
# m/s sultan disposal stores
# recytronics waste solutions llp
# we the recycling company
# aksha recycling and waste management private limited
# electro alloys recycling & transformation hub
# more bright e waste recycler pvt ltd
# techeco waste management llp
# kamal electronics refurbishing of e waste solutions
# hayat e-recyclers pvt ltd
# golden green recyclers
# hind recycling pvt ltd
# hsa green it e-waste
# progressive recycler llp
# ingram micro india private limited
# ecoli waste management pvt ltd
# rashi e waste solutions private limited
# enviro tech it solutions
# kwikstop recycling solutions pvt ltd
# pamp precision manufacturing india private limited
# 3r recycler pvt. ltd.
# e wardd and  co
# communications test design india private limited
# eco recycling limited plant 2
# mercury metal industries
# recotech e waste management
# aer worldwide india pvt ltd
# terranova eco management pvt ltd
# enviro green recycling
# home land enviro engineers india pvt ltd
# new india organics
# a one e-waste recycling
# basant cleanenviro limited
# sun e waste recycling co
# west land gadgetry llp
# alchemy recyclers private limited
# eco green recycling private limited
# mangalam ecs environment pvt ltd
# earthzone recycling private limited
# eximo recycling pvt ltd
# gng electronics pvt ltd
# rpn industries
# ar recyclers private limited
# ms pro world green pvt ltd
# asnco india pvt ltd
# muskmelon envtech pvt ltd
# ikon recyclers
# aptus e waste recycling pvt ltd
# e hasiru
# elgreen metex private limited
# green india e-waste and recycling opc pvt ltd
# rplanet integrated solution pvt ltd
# reteck envirotech india pvt ltd
# nvsp traders private limited
# green valley recycling private limited
# green tech recycling
# puthur infotech private limited
# av sourcing private limited
# hasan malik recycling private limited
# erecon recycling pvt.ltd
# lubrina recycling pvt ltd
# earth care e-waste private limited
# galaxy recycling
# pideax consulting pvt ltd
# technogreen recycling pvt. ltd.
# resource e waste solutions pvt ltd
# world wide recyclers
# binbag recycling services pvt ltd
# global international
# gauvins green management pvt ltd
# greenholics recyclers private limited
# silicon planet recycling private limited
# sahni enterprises
# electronic waste india
# green enviro management solutions llp
# jacsgreen recycling private limited
# meta tech
# ingram micro india pvt. ltd
# e-pragathi recycling pvt ltd
# deshwal waste management pvt ltd
# clean e waste recycling
# ash recyclers
# rewasto recycling
# bharat oil and waste management ltd.
# envirokare recycling solutions pvt ltd
# Comparison results saved to comparison_result.csv
