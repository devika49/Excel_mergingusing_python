# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python312\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

def extract_columns_to_csv_from_second_row(csv_file_path, columns_to_extract, new_column_names, output_csv_path):
    """
    Extract specific columns from the second row of a CSV file, rename them, and save them as a CSV file.
    Includes column 'Type' and extracts this column data too.
    
    Parameters:
    - csv_file_path: Path to the CSV file
    - columns_to_extract: List of column names to extract
    - new_column_names: List of new names for the extracted columns
    - output_csv_path: Path to save the extracted columns as a CSV file
    """
    try:
        # Read the CSV file and use the second row as column names
        sheet_data = pd.read_csv(csv_file_path, header=1)
        
        # Clean up column names by removing extra spaces and correcting known issues
        sheet_data.columns = sheet_data.columns.str.replace(' +', ' ', regex=True)  # Replace multiple spaces with a single space
        sheet_data.columns = sheet_data.columns.str.strip()  # Strip leading/trailing spaces

        # Print actual column names to help with debugging
        print("Actual columns in the file:", sheet_data.columns.tolist())
        
        # Add 'Type' to the list of columns to extract
        if 'Type' not in columns_to_extract:
            columns_to_extract.append('Type')
        
        # Validate if all specified columns exist in the CSV file
        missing_columns = [col for col in columns_to_extract if col not in sheet_data.columns]
        if missing_columns:
            print(f"The following columns were not found in the CSV file: {missing_columns}")
            return
        
        # Extract the specified columns
        extracted_columns = sheet_data[columns_to_extract].dropna()
        
        # Rename the extracted columns
        extracted_columns.columns = new_column_names
        
        # Save the extracted columns to a new CSV file
        extracted_columns.to_csv(output_csv_path, index=False)
        print(f"Columns have been successfully extracted and saved to '{output_csv_path}'.")
    
    except Exception as e:
        print(f"Error: {e}")

# Example usage with absolute path
csv_file_path = r'D:/Excel_mergingusing_python/Add Cpcb Data/MPCB Electronic Waste.csv'  # Adjust with the correct path
columns_to_extract = [
    'Name and Address of Industry',
    'Capacity Allotted as per\n Consent / Authorisation (MT/A)',  # Updated column name
    'E-mail Address',
    'Contact Number'
]  # List of column names to extract
new_column_names = [
    'Company Name',
    'Capacity Allotted (MT/A)',
    'Email Address',
    'Phone Number',
    'Type'  # Include 'Type' in the new column names list
]  # New names for the extracted columns
output_csv_path = 'output_file.csv'  # Path to save the output CSV file

# Call the function
extract_columns_to_csv_from_second_row(csv_file_path, columns_to_extract, new_column_names, output_csv_path)
# Out:
# Actual columns in the file: ['Sr. No.', 'Name and Address of Industry', 'Regional Office', 'Type', 'Capacity Allotted as per\n Consent / Authorisation (MT/A)', 'Consent / Authorization No. & Issue Date', 'Validity of\n Consent / Authorization', 'E-mail Address', 'Contact Number', 'Current Status']
# Columns have been successfully extracted and saved to 'output_file.csv'.

# %%
import pandas as pd
import re

def clean_company_name(csv_file_path, output_csv_path):
    try:
        # Load the CSV file into a Pandas DataFrame
        df = pd.read_csv(csv_file_path)

        # Regular expression to remove the address portion (e.g., Plot No., Tal., etc.)
        # This regex targets phrases like "Plot No.", "Tal.", numbers, and any commas or address details
        df['Company Name'] = df['Company Name'].apply(lambda x: re.sub(r',?(\s*(Plot No\.\s*|Tal\.\s*|District\s*|Dist\.\s*|No\.\s*|Nr\.\s*)[^,]+)', '', x))

        # Clean company name by removing any leftover unwanted characters
        df['Company Name'] = df['Company Name'].apply(lambda x: re.sub(r',.*', '', x))

        # Save the cleaned data to a new CSV file
        df.to_csv(output_csv_path, index=False)

        print(f"Cleaned data has been successfully saved to '{output_csv_path}'.")

    except Exception as e:
        print(f"Error: {e}")

# Example usage with the CSV file paths
csv_file_path = r'D:/Excel_mergingusing_python/Add Cpcb Data/output_file.csv'  # Path to the CSV file (the one with Company Name and address)
output_csv_path = 'cleaned_file.csv'  # Path to save the cleaned data

# Call the function
clean_company_name(csv_file_path, output_csv_path)
# Out:
# Cleaned data has been successfully saved to 'cleaned_file.csv'.

# %%
import pandas as pd

def match_and_save_data(csv_file1, csv_file2, output_csv_path):
    try:
        # Load both CSV files into Pandas DataFrames
        df1 = pd.read_csv(csv_file1)
        df2 = pd.read_csv(csv_file2)

        # Clean column names by stripping extra spaces and making sure they're uniform
        df1.columns = df1.columns.str.strip()
        df2.columns = df2.columns.str.strip()

        # Print the columns to debug and ensure that the data is loaded correctly
        print("Columns in file 1:", df1.columns.tolist())
        print("Columns in file 2:", df2.columns.tolist())

        # Merge the data based on 'Company Name' and 'Type' (exact match)
        matched_data = pd.merge(df1, df2, on=['Company Name', 'Type'], how='inner')

        # Save the matched data to a new CSV file
        matched_data.to_csv(output_csv_path, index=False)

        print(f"Matched data has been successfully saved to '{output_csv_path}'.")
    
    except Exception as e:
        print(f"Error: {e}")

# Example usage with the CSV file paths
csv_file1 = r'D:/Excel_mergingusing_python/Add Cpcb Data/matchingfile/Mpcb_final_data - Sheet1.csv'  # Path to the first CSV file (the one with Company Name, Type, etc.)
csv_file2 = r'D:/Excel_mergingusing_python/Add Cpcb Data/matchingfile/cleaned_file.csv'  # Path to the second CSV file (the one with Company Name, Type, etc.)
output_csv_path = 'matched_data.csv'  # Path to save the output CSV file with matched data

# Call the function
match_and_save_data(csv_file1, csv_file2, output_csv_path)
# Out:
# Columns in file 1: ['ID', 'Company Name', 'MATCH in mpcb', 'Info', 'Status', 'Type', 'Address', 'District', 'State', 'Capacity Allotted as per Consent / Authorisation (MT/A)', 'E-mail Address', 'Contact Number']
# Columns in file 2: ['Company Name', 'Capacity Allotted (MT/A)', 'Email Address', 'Phone Number', 'Type']
# Matched data has been successfully saved to 'matched_data.csv'.

# %%
import pandas as pd

def match_and_extract(csv_file_1, csv_file_2, output_csv_path):
    try:
        # Load the first CSV file (file with company data from MPCB)
        mpcb_data = pd.read_csv(csv_file_1)

        # Load the second CSV file (file with company name, capacity, etc.)
        company_data = pd.read_csv(csv_file_2)

        # Print actual column names for debugging purposes
        print("MPCB Data Columns:", mpcb_data.columns.tolist())
        print("Company Data Columns:", company_data.columns.tolist())

        # Merge the two dataframes on 'Company Name' and 'Type' to get matched rows
        matched_data = pd.merge(mpcb_data, company_data, how='inner', on=['Company Name', 'Type'])

        # Check if we got any matches
        if matched_data.empty:
            print("No matching data found.")
        else:
            # Save the matched data to a new CSV file
            matched_data.to_csv(output_csv_path, index=False)
            print(f"Matched data has been successfully saved to '{output_csv_path}'.")

    except Exception as e:
        print(f"Error: {e}")

# Example usage with file paths
csv_file_1 = r'D:/Excel_mergingusing_python/Add Cpcb Data/matchingfile/cleaned_file.csv'  # Path to the first CSV file (the one with MPCB data)
csv_file_2 = r'D:/Excel_mergingusing_python/Add Cpcb Data/matchingfile/Mpcb_final_data - Sheet1.csv'  # Path to the second CSV file (with company name, type, etc.)
output_csv_path = 'matched_data.csv'  # Path to save the output matched data

# Call the function
match_and_extract(csv_file_1, csv_file_2, output_csv_path)
# Out:
# MPCB Data Columns: ['Company Name', 'Capacity Allotted (MT/A)', 'Email Address', 'Phone Number', 'Type']
# Company Data Columns: ['ID', 'Company Name', 'MATCH in mpcb', 'Info', 'Status', 'Type', 'Address', 'District', 'State', 'Capacity Allotted as per Consent / Authorisation (MT/A)', 'E-mail Address', 'Contact Number']
# No matching data found.

# %%
import csv

# Input and output file paths
input_file = r'D:/Excel_mergingusing_python/Add Cpcb Data/matchingfile/cleaned_file.csv'  # Replace with your input CSV file path
output_file = 'output.csv'  # Replace with your desired output CSV file path

# Function to filter and rearrange CSV data
def filter_csv(input_file, output_file):
    with open(input_file, mode='r', newline='', encoding='utf-8') as infile, open(output_file, mode='w', newline='', encoding='utf-8') as outfile:
        reader = csv.DictReader(infile)
        fieldnames = reader.fieldnames
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)
        writer.writeheader()
        
        for row in reader:
            if row['Type'] in ['Recycler', 'Refurbisher']:
                writer.writerow(row)

# Call the function to filter and save the CSV
filter_csv(input_file, output_file)

print(f'Filtered CSV saved as {output_file}')
# Out:
# Filtered CSV saved as output.csv

# %%
import csv

# List of company names to filter (stripped and normalized)
company_names = [
    "ALFA TRADING COMPANY", "GLACIER WASTE MANAGEMENT LLP", "NATIONAL TRADING CORPORATION", 
    "RAZA ENTERPRISES", "RECYCLE MITRA ECO CARE LLP", "SHABBIR TRADERS", "UNIQUE RECYCLING", 
    "UNIVERSAL WASTE MANAGEMENT", "AQSA STAMPING", "GO GREEN E-RECYCLING", "MASSTECH RECYCLING LLP", 
    "MOONLAXMI-E-WASTE & RECYCLING SOLUTIONS LLP", "PRABHUNATH TRADERS", "RECYCLE MITRA ECO CARE LLP", 
    "SADAB TRADERS", "S. K. ENTERPRISES", "TRISHULIN ENTERPRISES", "WONDER PRINT TECHNOLOGIES", 
    "ECO TECH RECYCLING", "EMS SCRAPO", "GREENSCAPE ECO MANAGEMENT PRIVATE LIMITED", "J K CORPORATION", 
    "KRISHNA METAL REFINERY", "MAHARASHTRA ENTERPRISES", "MAHESH TRADERS", "ROSHANI SCRAP CENTER", 
    "S K ENTERPRISES", "ALFA TRADING COMPANY", "ARSH RECYCLING PRIVATE LIMITED", "ECO FRIEND INDUSTRIES", 
    "ECO RECYCLING LIMITED", "ECO RESET PRIVATE LIMITED", "ECOSTAR RECYCLING", "GLACIER WASTE MANAGEMENT LLP", 
    "GREENBAY ENTERPRISES", "GREEN CARE E WASTE RECYCLING", "GREEN LIFE E WASTE RECYCLING PVT LTD", 
    "NATIONAL TRADING CORPORATION", "RAZA ENTERPRISES", "RECYCLE MITRA ECO CARE LLP", 
    "SCAPE E RECYCLER PRIVATE LIMITED", "SHABBIR TRADERS", "S V GREENTECH PRIVATE LIMITED", 
    "THRECO RECYCLING LLP", "UNIQUE RECYCLING", "UNIVERSAL WASTE MANAGEMENT", "VOZON COMSOF PVT LTD", 
    "WESTERN RECYCLER", "ARSH RECYCLING PRIVATE LIMITED", "ECO FRIEND INDUSTRIES", "ECO RECYCLING LIMITED", 
    "ECO RESET PRIVATE LIMITED", "ECOSTAR RECYCLING", "GREEN CARE E WASTE RECYCLING", 
    "GREEN LIFE E WASTE RECYCLING PVT LTD", "SCAPE E RECYCLER PRIVATE LIMITED", "S V GREENTECH PRIVATE LIMITED", 
    "THRECO RECYCLING LLP", "VOZON COMSOF PVT LTD", "WESTERN RECYCLER", "AQSA STAMPING", "ECO RECYCLING LIMITED", 
    "ECO TECH RECYCLING", "EMS SCRAPO", "GO GREEN E-RECYCLING", "GREENSCAPE ECO MANAGEMENT PRIVATE LIMITED", 
    "J K CORPORATION", "KRISHNA METAL REFINERY", "MAHARASHTRA ENTERPRISES", "MAHESH TRADERS", 
    "MASSTECH RECYCLING LLP", "MOONLAXMI-E-WASTE & RECYCLING SOLUTIONS LLP", "PRABHUNATH TRADERS", 
    "RECYCLE MITRA ECO CARE LLP", "ROSHANI SCRAP CENTER", "SADAB TRADERS", "S K ENTERPRISES", 
    "S. K. ENTERPRISES", "TRISHULIN ENTERPRISES", "WONDER PRINT TECHNOLOGIES"
]

# Strip spaces and normalize to lowercase for comparison
company_names = [name.strip().lower() for name in company_names]

# Input and output file paths
input_file = r'D:/Excel_mergingusing_python/Add Cpcb Data/matchingfile/cleaned_file.csv'  # Ensure correct path
output_file = 'filtered_companies.csv'  # Ensure write permission

# Function to filter CSV data
def filter_companies(input_file, output_file, company_names):
    with open(input_file, mode='r', newline='', encoding='utf-8') as infile, open(output_file, mode='w', newline='', encoding='utf-8') as outfile:
        reader = csv.DictReader(infile)
        fieldnames = reader.fieldnames
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)
        writer.writeheader()  # Write the header row
        
        # Print headers for debugging
        print(f"Headers in CSV: {fieldnames}")
        
        for row in reader:
            company_name = row['Company Name'].strip().lower()  # Strip spaces and normalize case
            # Debug print to see the matching process
            print(f"Checking {company_name} against filtered list.")
            if company_name in company_names:
                writer.writerow(row)

# Call the function to filter and save the CSV
filter_companies(input_file, output_file, company_names)

print(f'Filtered CSV saved as {output_file}')
# Out:
# Headers in CSV: ['Company Name', 'Capacity Allotted (MT/A)', 'Email Address', 'Phone Number', 'Type']
# Checking arihant e recycling pvt ltd against filtered list.
# Checking we-the recycling company against filtered list.
# Checking techeco e-waste namo llp against filtered list.
# Checking threco recycling llp against filtered list.
# Checking hi-tech recycling (i) pvt. ltd against filtered list.
# Checking justdispose recycling pvt ltd. (unit- ii) against filtered list.
# Checking e-incarnation recycling pvt. ltd. against filtered list.
# Checking eco recycling limited
#  bldg
#  vasai (e) against filtered list.
# Checking evergreen recyclekaro india pvt.
#  ltd. against filtered list.
# Checking eco reset private limited against filtered list.
# Checking s v greentech private limited against filtered list.
# Checking global e-recycling pvt ltd.
#  wakanpada dhaniv against filtered list.
# Checking green it recycling center pvt ltd against filtered list.
# Checking green india e-waste & recycling opc pvt. ltd. against filtered list.
# Checking suritex pvt. ltd. against filtered list.
# Checking green valley e waste management pvt ltd against filtered list.
# Checking sayma e-waste solutions against filtered list.
# Checking green valley e-waste management pvt. ltd. against filtered list.
# Checking western recycler against filtered list.
# Checking tarai projects pvt. ltd. against filtered list.
# Checking jeenali trading & comm. serv. pvt. ltd. against filtered list.
# Checking unique recycling
#  post nanekarwadi against filtered list.
# Checking new india recyclers against filtered list.
# Checking electrofine recycling (opc) private limited
#  gut against filtered list.
# Checking binbay recycling pvt. ltd.
#  village gauripada against filtered list.
# Checking greenbay enterprises
#  shed
#  katraj saswad road against filtered list.
# Checking green life e waste recycling pvt ltd against filtered list.
# Checking bhangarwala waste management pvt ltd.
#  new s. against filtered list.
# Checking comnet e-waste llp
#  gut against filtered list.
# Checking ecolayer e-waste recycling
#  s.
#  village poman against filtered list.
# Checking bhagyalakshmi laboratories limited against filtered list.
# Checking eco-recycling ltd. against filtered list.
# Checking gnr recycling india pvt ltd
#  s. against filtered list.
# Checking e-survival recycling private limited against filtered list.
# Checking green enviro management
#  solutions llp against filtered list.
# Checking trans thane creek waste
#  management association
#  p-128 against filtered list.
# Checking mercury metal industries (unit iii) against filtered list.
# Checking aman e-waste recyclers pvt ltd.
#  s. against filtered list.
# Checking eco friend industries against filtered list.
# Checking pune green electronic waste recycler pvt. ltd. against filtered list.
# Checking e-frontline recycling pvt. ltd. gat
#  warehouse against filtered list.
# Checking jrs recycling solutions pvt. ltd. gala against filtered list.
# Checking kuldeep green recyclers private limited against filtered list.
# Checking vozon comsof pvt ltd against filtered list.
# Checking j k corporation
#  survey against filtered list.
# Checking ambar enterprises
#  s. against filtered list.
# Checking kohinoor e-waste recycling pvt. ltd. gut against filtered list.
# Checking poona e-waste solutions
#  s. against filtered list.
# Checking j choudhary & company against filtered list.
# Checking e-refine corporation against filtered list.
# Checking wonder print technologies against filtered list.
# Checking masstech recycling llp against filtered list.
# Checking nasib scrap centre
#  moi kuruli chakan against filtered list.
# Checking roshani scrap center
#  gut
#  pune-411062 against filtered list.
# Checking gng electronics pvt. ltd.
#  midc turbhe against filtered list.
# Checking diamond machinery tools
#  gausiya market against filtered list.
# Checking new india recyclers against filtered list.
# Checking jai ambe enterprises
#  s. against filtered list.
# Checking moonlaxmi-e-waste & recycling solutions llp
#  pune against filtered list.
# Checking big bull recyclers private limited against filtered list.
# Checking zakiya amin enterprises
#  nalasopara against filtered list.
# Checking maharashtra enterprises against filtered list.
# Checking amin industries against filtered list.
# Checking erecon recycling pvt. ltd. against filtered list.
# Checking go green e-recycling
#  sr. against filtered list.
# Checking sai enterprises against filtered list.
# Checking somnath industries pvt ltd..
#  os-56 against filtered list.
# Checking bombay scrap traders
#  gut against filtered list.
# Checking afton e-waste recycling
#  s.
#  janta market against filtered list.
# Checking ask steel
#  gat against filtered list.
# Checking m. s. malik against filtered list.
# Checking aman e-waste disposal
#  s. against filtered list.
# Checking glacier waste management llp against filtered list.
# Checking trishulin enterprises
#  musalgaon against filtered list.
# Checking kesariya metal conrporation
#  gat against filtered list.
# Checking raj enterprises
#  gut against filtered list.
# Checking imagine marketing limited against filtered list.
# Checking shuaib traders
#  gat against filtered list.
# Checking deshwal waste management pvt.
#  ltd. against filtered list.
# Checking dev it serv pvt ltd
#  gat against filtered list.
# Checking shree recyclers against filtered list.
# Checking lexim international pvt. ltd. against filtered list.
# Checking naaz trading company
#  gat against filtered list.
# Checking rajmudra trading
#  gat against filtered list.
# Checking v k metal corporation gut against filtered list.
# Checking clean e-waste recycling against filtered list.
# Checking lilashana sales against filtered list.
# Checking national traders against filtered list.
# Checking s. s. e-waste recyclers against filtered list.
# Checking ag enterprises against filtered list.
# Checking aman trading co. f/1
#  (w) against filtered list.
# Checking amiable electroning pvt. ltd.
#  nerul against filtered list.
# Checking e-recon recycling pvt. ltd. against filtered list.
# Checking eco layer e-waste recycling
#  estate
#  vasai e against filtered list.
# Checking prabhunath traders against filtered list.
# Checking kalawishwa electrical against filtered list.
# Checking royal scrap traders against filtered list.
# Checking maharashtra enterprises against filtered list.
# Checking sigma enterprises against filtered list.
# Checking saani enterprises against filtered list.
# Checking baban plastic
#  sajapur against filtered list.
# Checking sultan disposal stores against filtered list.
# Checking indian scrap traders against filtered list.
# Checking bombay recyclers pvt. ltd.
#  industrial park against filtered list.
# Checking hari om scrap traders
#  central against filtered list.
# Checking go green recycling
#  mumbai against filtered list.
# Checking new india scrap traders against filtered list.
# Checking navkar recycling
#  dahisar against filtered list.
# Checking harshita green recyclers against filtered list.
# Checking vora computers pvt. ltd. against filtered list.
# Checking clean tech
#  dist: thane against filtered list.
# Checking green it recycling centre pvt. ltd. against filtered list.
# Checking bhavesh enterprises against filtered list.
# Checking om recycling
#  peth against filtered list.
# Checking process recycling against filtered list.
# Checking new shivam enteprises against filtered list.
# Checking mahesh traders against filtered list.
# Checking manihar enterprises against filtered list.
# Checking asquare industrial solutions against filtered list.
# Checking map trading company against filtered list.
# Checking environment experts
#  mumbai against filtered list.
# Checking green enviro services
#  wasali against filtered list.
# Checking bsqaure e-waste recyclers against filtered list.
# Checking sk e-waste disposal against filtered list.
# Checking mahalaxmi e- recyclers pvt. ltd. against filtered list.
# Checking kapila enterprises
#  at. post. supa against filtered list.
# Checking aqsa stamping against filtered list.
# Checking cpg shell mould & casting against filtered list.
# Checking rolex entrprises
#  hissa against filtered list.
# Checking eco tech recycling
#  dist: palghar. against filtered list.
# Checking r t corporation against filtered list.
# Checking ecostar recycling
#  thane-400612. against filtered list.
# Checking bombay metal works against filtered list.
# Checking ancus india reprocessing pvt. ltd. against filtered list.
# Checking progressive recycler llp. midc
#  chakan industrial area (ph-ii) against filtered list.
# Checking envirocare recycling pvt. ltd. against filtered list.
# Checking green planet recycling solutions against filtered list.
# Checking a. s. enterprises
#  400089 against filtered list.
# Checking rcube recycling pvt ltd. against filtered list.
# Checking alfa trading co.
#  road against filtered list.
# Checking universal waste management
#  khairani road
#  400072 - 400072 against filtered list.
# Checking sadab traders against filtered list.
# Checking gng electronics pvt. ltd. against filtered list.
# Checking arsh recycling private limited
#  ranjangaon ganpati against filtered list.
# Checking sahara enterprises against filtered list.
# Checking anand computer system against filtered list.
# Checking bharat e waste recycling co. against filtered list.
# Checking chaudhary metal. 80/2 against filtered list.
# Checking e clean e green recycling against filtered list.
# Checking earth sense recycle pvt. ltd. against filtered list.
# Checking regreen recycling against filtered list.
# Checking solapur econ recyfine against filtered list.
# Checking greenscape eco management private limited
#  410501 against filtered list.
# Checking krishna metal refinery against filtered list.
# Checking kuldeep e-waste disposals
#  katraj against filtered list.
# Checking mac fix station
#  mumbai suburban - 400052 against filtered list.
# Checking manish metal
#  ashtekar bangla against filtered list.
# Checking s.k. enterprises against filtered list.
# Checking bke recycling against filtered list.
# Checking nagraj e-waste recycling against filtered list.
# Checking new ecotech recycling against filtered list.
# Checking r.k.e-recycling international llp gala no.-2 against filtered list.
# Checking cbs e-waste recycling industries
#  g. against filtered list.
# Checking j. s. enterprises against filtered list.
# Checking scape e recycler private limited
#  431511 against filtered list.
# Checking nicholas recycling private
#  limited against filtered list.
# Checking k. g. n. traders against filtered list.
# Checking the2bros
#  chandivali
#  400072 against filtered list.
# Checking right e-waste recycle against filtered list.
# Checking ems scrapo against filtered list.
# Checking mayra corporation against filtered list.
# Checking perfect e-waste recyclers against filtered list.
# Checking sahara traders against filtered list.
# Checking trekomac refurbs pvt. ltd. against filtered list.
# Checking unity enterprises against filtered list.
# Checking shabbir traders against filtered list.
# Checking recycling future
#  bhangarpada against filtered list.
# Checking star envo recycling (i) private limited against filtered list.
# Checking shifa traders
#  moshi road against filtered list.
# Checking s. n. brothers
#  dist palghar against filtered list.
# Checking yasin scrap against filtered list.
# Checking reteck envirotech pvt. ltd. against filtered list.
# Checking vatsala enterprises
#  village rajapur against filtered list.
# Checking s k enterprises against filtered list.
# Checking om r v interiors against filtered list.
# Checking mauli metals
#  kadachi wadi against filtered list.
# Checking grade infratech pvt. ltd. against filtered list.
# Checking general technologies india pvt ltd against filtered list.
# Checking national trading corporation
#  pimpri against filtered list.
# Checking spas computers pvt. ltd. 7 & 12 against filtered list.
# Checking noble trading company against filtered list.
# Checking pakeeza traders against filtered list.
# Checking d trading company
#  dist- pune against filtered list.
# Checking rajhans ferrous scrap trade private limited against filtered list.
# Checking clean planet llp
#  42 against filtered list.
# Checking jupiter enterprises
#  and 09 gilbert compound against filtered list.
# Checking biyani polymers against filtered list.
# Checking alfa trading company against filtered list.
# Checking lico materials pvt ltd against filtered list.
# Checking recycle mitra eco care llp against filtered list.
# Checking nizam enterprises
#  jyot industrial premises co op society ltd against filtered list.
# Checking haq processing pvt. ltd.
#  vasai against filtered list.
# Checking muskmelon envtech pvt. ltd. godown d-4
#  nagar road against filtered list.
# Checking green clean recycling
#  hissa no 4 against filtered list.
# Checking s. k. enterprises against filtered list.
# Checking valji khimji & co.
#  gut against filtered list.
# Checking anitha sri recycling against filtered list.
# Checking naved enterprises against filtered list.
# Checking e cycle & company against filtered list.
# Checking saraswati enterprises against filtered list.
# Checking aman steel enterprises against filtered list.
# Checking avis group
#  nagari against filtered list.
# Checking mukesh metal
#  panvel road against filtered list.
# Checking wave e waste recycling pvt ltd. sr. against filtered list.
# Checking a k barrels and generals scrap against filtered list.
# Checking savita barrels
#  mumbai. - 400086 against filtered list.
# Checking lucky enterprises against filtered list.
# Checking raza enterprises against filtered list.
# Checking national sales corporation against filtered list.
# Checking green care e waste recycling against filtered list.
# Checking z a barrel suppliers
#  thane against filtered list.
# Checking bakruddin din mohammad against filtered list.
# Checking eco tantra llp against filtered list.
# Filtered CSV saved as filtered_companies.csv
